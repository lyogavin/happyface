# %%
# !pwd
# Out:
# /Users/l_y_o/Work/flux-training/notebooks

# %%
# load /Users/l_y_o/Work/happyface/pseo/ai_girls_sample_images.json

images = json.load(open('/Users/l_y_o/Work/happyface/pseo/ai_girls_sample_images.json'))

# show the first image
images[0]

# show the last image
images[-1]
# Out:
# 'https://scontent-dfw5-1.cdninstagram.com/v/t39.30808-6/480111205_614516708177388_5606094798829422550_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkZFRUQuaW1hZ2VfdXJsZ2VuLjE2Mzl4MjA0OC5zZHIuZjMwODA4LmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=scontent-dfw5-1.cdninstagram.com&_nc_cat=100&_nc_oc=Q6cZ2QGgZgJmFnqt3zUxmN8Umaz3EXYZ2-APpmEY-AZEc40r5ZLauOSpn4XGoec1-HkX-v4&_nc_ohc=NH5kl6ffFoMQ7kNvgFjKN1G&_nc_gid=Bggjtait2N8u54unKWC_6w&edm=APoiHPcAAAAA&ccb=7-5&ig_cache_key=MzI1NzE1Njc5MTgzNTk3NDg2Nw%3D%3D.3-ccb7-5&oh=00_AYETAup4uWa1dQWQY6-XgshmJqPybmhCBDITY5Zy7nCIng&oe=67F0C627&_nc_sid=22de04'

# %%
import json
import time
import requests
import random
import os
import re
from typing import Optional, Dict, List, Any


def get_image_tags(
    image_url: str,
    comfy_server_url: str = "http://72.70.187.181:50346/",
    workflow_file: str = "/Users/l_y_o/Work/happyface/pseo/image-tagger-api.json",
    max_retries: int = 3,
    poll_interval: float = 2.0,
    timeout: int = 300
) -> Optional[Dict[str, Any]]:
    """
    Get tags for an image using ComfyUI workflow.
    
    Args:
        image_url: URL of the image to tag
        comfy_server_url: URL of the ComfyUI server
        workflow_file: Path to the workflow JSON file
        max_retries: Maximum number of retries for the job submission
        poll_interval: Time in seconds between status check polls
        timeout: Maximum time in seconds to wait for job completion
        
    Returns:
        Dictionary containing the tags and confidence scores, or None if tagging failed
    """
    # Load the workflow
    try:
        with open(workflow_file, 'r') as f:
            workflow = json.load(f)
    except Exception as e:
        print(f"Error loading workflow file: {str(e)}")
        return None
    
    # Modify the image URL in the workflow
    # Find the LoadImageFromUrlOrPath node
    for node_id, node in workflow.items():
        if node.get("class_type") == "LoadImageFromUrlOrPath":
            # Replace the image URL
            node["inputs"]["url_or_path"] = image_url
            break
    
    # Prepare the API request
    prompt_api_url = f"{comfy_server_url}/prompt"
    
    # Prepare the payload
    payload = {
        "prompt": workflow,
        "client_id": f"comfy_tagger_{int(time.time())}"
    }
    
    # Submit the job
    job_id = None
    for attempt in range(max_retries):
        try:
            print(f"Submitting tagging job attempt {attempt+1}/{max_retries}...")
            response = requests.post(prompt_api_url, json=payload)
            response.raise_for_status()
            response_data = response.json()
            job_id = response_data.get("prompt_id")
            if job_id:
                print(f"Successfully submitted job with ID: {job_id}")
                break
        except Exception as e:
            print(f"Attempt {attempt+1}/{max_retries} - Error submitting job: {str(e)}")
            if attempt < max_retries - 1:
                sleep_time = 2 ** attempt  # Exponential backoff
                print(f"Retrying in {sleep_time} seconds...")
                time.sleep(sleep_time)
    
    if not job_id:
        print("Failed to submit job after all retries")
        return None
    
    # Poll for job completion using the job history endpoint
    start_time = time.time()
    job_api_url = f"{comfy_server_url}/history/{job_id}"
    queue_api_url = f"{comfy_server_url}/queue"
    
    print(f"Waiting for job {job_id} to complete...")
    
    while time.time() - start_time < timeout:
        try:
            # Check queue status to see if our job is running
            queue_response = requests.get(queue_api_url)
            if queue_response.status_code == 200:
                queue_data = queue_response.json()
                running = queue_data.get("running", [])
                queue_remaining = queue_data.get("queue_remaining", 0)
                
                if running:
                    for job in running:
                        # Check if our job is running
                        if job.get("prompt_id") == job_id:
                            progress = job.get("progress", 0)
                            print(f"Job running: {progress*100:.1f}% complete")
                elif queue_remaining > 0:
                    print(f"Job queued. Position in queue: {queue_remaining}")
            
            # Get job status from history
            job_response = requests.get(job_api_url)
            
            # Skip if job not found yet
            if job_response.status_code == 404:
                print(f"Job {job_id} not found in history yet. Waiting...")
                time.sleep(poll_interval)
                continue
                
            job_response.raise_for_status()
            job_data = job_response.json()

            if job_data == {}:
                print(f"Job {job_id} not found in history yet. Waiting...")
                time.sleep(poll_interval)
                continue
            
            # The response has the job_id as the key
            if job_id in job_data:
                job_info = job_data[job_id]
                
                # Check for outputs
                outputs = job_info.get("outputs", {})
                if outputs:
                    # Check output from WD14 Tagger node (node 1)
                    if "1" in outputs and outputs["1"]:
                        if "tags" in outputs["1"]:
                            tags_data = outputs["1"]["tags"]
                            print(f"Successfully extracted image tags")
                            
                            # Parse tags output
                            # The output format may vary based on the tagger implementation
                            # Here we handle common format: a string of comma-separated tags
                            if isinstance(tags_data, str):
                                tags_list = [tag.strip() for tag in tags_data.split(',')]
                                return {"tags": tags_list}
                            elif isinstance(tags_data, list):
                                return {"tags": tags_data}
                            elif isinstance(tags_data, dict):
                                return tags_data
                            else:
                                print(f"Unexpected tags format: {type(tags_data)}")
                                return {"raw_tags": tags_data}
                
                # Check if job is completed
                status = job_info.get("status", {})
                if status:
                    completed = status.get("completed", False)
                    status_str = status.get("status_str", "")
                    
                    if completed:
                        if status_str == "success":
                            # Job completed successfully but we didn't find tags yet
                            if outputs:
                                print("Job completed successfully but no tags found in outputs")
                                print(f"Available outputs: {json.dumps(outputs, indent=2)}")
                                # Return whatever outputs we have
                                return {"outputs": outputs}
                            else:
                                print("Job completed but no outputs available yet")
                        else:
                            print(f"Job completed with status: {status_str}")
                            return None
            else:
                print(f"Job {job_id} found in history but unexpected response format, data: {job_data}")
        
        except Exception as e:
            print(f"Error checking job status: {str(e)}")
        
        # Wait before next poll
        time.sleep(poll_interval)
    
    print(f"Timeout reached after {timeout} seconds")
    return None


def tag_image(image_url: str, max_attempts: int = 3, **kwargs) -> Optional[Dict[str, Any]]:
    """
    Tag an image with retry logic
    
    Args:
        image_url: URL of the image to tag
        max_attempts: Maximum number of tagging attempts
        **kwargs: Additional arguments for get_image_tags
        
    Returns:
        Dictionary of image tags, or None if tagging failed
    """
    for attempt in range(max_attempts):
        try:
            print(f"Tagging attempt {attempt+1}/{max_attempts}")
            print(f"Image URL: {image_url}")
            
            # Call the ComfyUI tagging function
            result = get_image_tags(image_url, **kwargs)
            
            if result:
                return result
            print(f"Attempt {attempt+1} failed to return valid tags")
            
        except Exception as e:
            print(f"Error during tagging attempt {attempt+1}: {str(e)}")
            import traceback
            traceback.print_exc()
        
        # Only sleep if we're going to retry
        if attempt < max_attempts - 1:
            backoff = 2 ** attempt
            print(f"Retrying in {backoff} seconds...")
            time.sleep(backoff)
    
    print(f"Failed to tag image after {max_attempts} attempts")
    return None


# Example usage:
if __name__ == "__main__":
    # Example image URL
    test_image_url = "https://scontent-dfw5-1.cdninstagram.com/v/t39.30808-6/479057926_613417618287297_1751938931122809423_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkZFRUQuaW1hZ2VfdXJsZ2VuLjE3MTF4MjA0OC5zZHIuZjMwODA4LmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=scontent-dfw5-1.cdninstagram.com&_nc_cat=109&_nc_oc=Q6cZ2QF9dRTzTGD_lefaDT1Mqz4lR6Bu7JW-ThSDeXBH81KJ2HA-jn3uF9vRGtEmY6LFDMQ&_nc_ohc=xS_ajUFYFFEQ7kNvgHi9h5Y&_nc_gid=d81vSigMucAMuP8ftgq4Ug&edm=APoiHPcAAAAA&ccb=7-5&ig_cache_key=MzI1ODYxOTkwMDcwNjYwNDM3MA%3D%3D.3-ccb7-5&oh=00_AYFJQ2QxAh3r7tZqGbihRFVRyOQKJ5ySVlh198uIu1aJrA&oe=67F0B954&_nc_sid=22de04"
    
    # Tag the image
    tags_result = tag_image(
        image_url=test_image_url,
        workflow_file="/Users/l_y_o/Work/happyface/pseo/image-tagger-api.json"
    )
    
    if tags_result:
        print(f"Image tags: {json.dumps(tags_result, indent=2)}")
    else:
        print("Image tagging failed")
# Out:
# Tagging attempt 1/3
# Image URL: https://scontent-dfw5-1.cdninstagram.com/v/t39.30808-6/479057926_613417618287297_1751938931122809423_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkZFRUQuaW1hZ2VfdXJsZ2VuLjE3MTF4MjA0OC5zZHIuZjMwODA4LmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=scontent-dfw5-1.cdninstagram.com&_nc_cat=109&_nc_oc=Q6cZ2QF9dRTzTGD_lefaDT1Mqz4lR6Bu7JW-ThSDeXBH81KJ2HA-jn3uF9vRGtEmY6LFDMQ&_nc_ohc=xS_ajUFYFFEQ7kNvgHi9h5Y&_nc_gid=d81vSigMucAMuP8ftgq4Ug&edm=APoiHPcAAAAA&ccb=7-5&ig_cache_key=MzI1ODYxOTkwMDcwNjYwNDM3MA%3D%3D.3-ccb7-5&oh=00_AYFJQ2QxAh3r7tZqGbihRFVRyOQKJ5ySVlh198uIu1aJrA&oe=67F0B954&_nc_sid=22de04
# Submitting tagging job attempt 1/3...
# Successfully submitted job with ID: 337e6c19-bb63-499e-9112-4056a5892ffb
# Waiting for job 337e6c19-bb63-499e-9112-4056a5892ffb to complete...
# Job 337e6c19-bb63-499e-9112-4056a5892ffb not found in history yet. Waiting...
# Job 337e6c19-bb63-499e-9112-4056a5892ffb not found in history yet. Waiting...
# Successfully extracted image tags
# Image tags: {
#   "tags": [
#     "1girl, solo, long_hair, breasts, looking_at_viewer, smile, large_breasts, brown_hair, thighhighs, navel, cleavage, brown_eyes, underwear, panties, artist_name, indoors, bra, blurry, lips, black_panties, window, watermark, underwear_only, lingerie, curtains, black_bra, web_address, garter_belt, realistic"
#   ]
# }

# %%
# iter over the images and tag them
from tqdm import tqdm
image_info = {}
for image in tqdm(images):
    tags = tag_image(image)
    image_info[image] = tags

# %%
# save the images with tags
json.dump(images, open('/Users/l_y_o/Work/happyface/pseo/ai_girls_sample_images_tagged.json', 'w'))

# %%
ai_girls_types = [
  'nude girl',
  'sexy girl',
  'hot girl',
  'little girl',
  'teen girl',
  'nn girl',
  'bikini girl',
  'anime girl',
  'tween girl', 
  'girls porn',
  'young girl',
  'girl in panties',
  'cute girl',
  'girl in underwear',
  'girls kissing',
  'school girls',
  'asign girls',
  'girl in lingerie',
  'girl satin',
  'muscle girl',
  'beach girl',
  'topless girl',
  'petite girl',
  'pregnant girl',
  'valhalla girl', 
  'asian girls',
]

# %%
import json
import time
import requests
import random
import os
import re
from typing import Optional, Dict, Any


def generate_image_with_comfyui(
    prompt: str,
    comfy_server_url: str = "http://72.70.187.181:50346",
    workflow_file: str = "/Users/l_y_o/Work/happyface/pseo/flux-nsfw-upload-api.json",
    seed: Optional[int] = None,
    max_retries: int = 3,
    poll_interval: float = 2.0,
    timeout: int = 300
) -> Optional[str]:
    """
    Generate an image using ComfyUI workflow with the given prompt.
    The workflow will upload the image to Supabase storage.
    
    Args:
        prompt: The text prompt to use for image generation
        comfy_server_url: URL of the ComfyUI server
        workflow_file: Path to the workflow JSON file
        seed: Random seed for image generation (if None, a random seed will be used)
        max_retries: Maximum number of retries for the job submission
        poll_interval: Time in seconds between status check polls
        timeout: Maximum time in seconds to wait for job completion
        
    Returns:
        String URL of the generated image in Supabase, or None if generation failed
    """
    # Load the workflow
    try:
        with open(workflow_file, 'r') as f:
            workflow = json.load(f)
    except Exception as e:
        print(f"Error loading workflow file: {str(e)}")
        return None
    
    # Modify the prompt in the workflow
    # Find the CLIPTextEncode node (node 6 in the workflow)
    for node_id, node in workflow.items():
        if node.get("class_type") == "CLIPTextEncode":
            # Replace the prompt
            node["inputs"]["text"] = prompt
            break
    
    # Generate a random seed if not provided
    if seed is None:
        seed = random.randint(0, 2**32 - 1)
    
    # Find the RandomNoise node and update the seed
    for node_id, node in workflow.items():
        if node.get("class_type") == "RandomNoise":
            node["inputs"]["noise_seed"] = seed
            break
    
    # Prepare the API request
    prompt_api_url = f"{comfy_server_url}/prompt"
    
    # Prepare the payload
    payload = {
        "prompt": workflow,
        "client_id": f"comfy_generator_{int(time.time())}"
    }
    
    # Submit the job
    job_id = None
    for attempt in range(max_retries):
        try:
            print(f"Submitting generation job attempt {attempt+1}/{max_retries}...")
            response = requests.post(prompt_api_url, json=payload)
            response.raise_for_status()
            response_data = response.json()
            job_id = response_data.get("prompt_id")
            if job_id:
                print(f"Successfully submitted job with ID: {job_id}")
                break
        except Exception as e:
            print(f"Attempt {attempt+1}/{max_retries} - Error submitting job: {str(e)}")
            if attempt < max_retries - 1:
                sleep_time = 2 ** attempt  # Exponential backoff
                print(f"Retrying in {sleep_time} seconds...")
                time.sleep(sleep_time)
    
    if not job_id:
        print("Failed to submit job after all retries")
        return None
    
    # Poll for job completion using the job history endpoint
    start_time = time.time()
    job_api_url = f"{comfy_server_url}/history/{job_id}"
    queue_api_url = f"{comfy_server_url}/queue"
    
    print(f"Waiting for job {job_id} to complete...")
    
    while time.time() - start_time < timeout:
        try:
            # Check queue status to see if our job is running
            queue_response = requests.get(queue_api_url)
            if queue_response.status_code == 200:
                queue_data = queue_response.json()
                running = queue_data.get("running", [])
                queue_remaining = queue_data.get("queue_remaining", 0)
                
                if running:
                    for job in running:
                        # Check if our job is running
                        if job.get("prompt_id") == job_id:
                            progress = job.get("progress", 0)
                            print(f"Job running: {progress*100:.1f}% complete")
                elif queue_remaining > 0:
                    print(f"Job queued. Position in queue: {queue_remaining}")
            
            # Get job status from history
            job_response = requests.get(job_api_url)
            
            # Skip if job not found yet
            if job_response.status_code == 404:
                print(f"Job {job_id} not found in history yet. Waiting...")
                time.sleep(poll_interval)
                continue
                
            job_response.raise_for_status()
            job_data = job_response.json()

            if job_data == {}:
                print(f"Job {job_id} not found in history yet. Waiting...")
                time.sleep(poll_interval)
                continue
            
            # The response has the job_id as the key
            if job_id in job_data:
                job_info = job_data[job_id]
                
                # Check for outputs
                outputs = job_info.get("outputs", {})
                if outputs:
                    # Check node 57 (Display Any rgthree)
                    if "57" in outputs and outputs["57"]:
                        # For text output that contains the URL
                        if "text" in outputs["57"]:
                            for text_item in outputs["57"]["text"]:
                                if isinstance(text_item, str) and "http" in text_item:
                                    # Extract URL
                                    url_pattern = r'https?://\S+'
                                    match = re.search(url_pattern, text_item)
                                    if match:
                                        supabase_url = match.group(0)
                                        print(f"Successfully generated image: {supabase_url}")
                                        return supabase_url
                    
                    # Check for Supabase uploader output directly (node 55)
                    if "55" in outputs:
                        print("Found Supabase uploader output")
                        # Extract URL from Supabase uploader output
                        if "url" in outputs["55"]:
                            supabase_url = outputs["55"]["url"]
                            print(f"Successfully generated image: {supabase_url}")
                            return supabase_url
                        elif isinstance(outputs["55"], str) and "http" in outputs["55"]:
                            # Try to extract URL from string
                            url_pattern = r'https?://\S+'
                            match = re.search(url_pattern, outputs["55"])
                            if match:
                                supabase_url = match.group(0)
                                print(f"Successfully generated image: {supabase_url}")
                                return supabase_url
                        else:
                            # If the URL isn't in an expected format, return whatever is available
                            print(f"Unexpected format from Supabase uploader: {outputs['55']}")
                            return str(outputs["55"])
                
                # Check if job is completed
                status = job_info.get("status", {})
                if status:
                    completed = status.get("completed", False)
                    status_str = status.get("status_str", "")
                    
                    if completed:
                        if status_str == "success":
                            # Job completed successfully but we didn't find URL yet
                            if outputs:
                                print("Job completed successfully but no URL found in outputs")
                                print(f"Available outputs: {json.dumps(outputs, indent=2)}")
                            else:
                                print("Job completed but no outputs available yet")
                        else:
                            print(f"Job completed with status: {status_str}")
                            return None
            else:
                print(f"Job {job_id} found in history but unexpected response format, data: {job_data}")
        
        except Exception as e:
            print(f"Error checking job status: {str(e)}")
        
        # Wait before next poll
        time.sleep(poll_interval)
    
    print(f"Timeout reached after {timeout} seconds")
    return None


def generate_image(prompt: str, max_attempts: int = 3, **kwargs) -> Optional[str]:
    """
    Generate an image with retry logic
    
    Args:
        prompt: The text prompt for image generation
        max_attempts: Maximum number of generation attempts
        **kwargs: Additional arguments for generate_image_with_comfyui
        
    Returns:
        String URL of the generated image, or None if generation failed
    """
    for attempt in range(max_attempts):
        try:
            print(f"Generation attempt {attempt+1}/{max_attempts}")
            print(f"Prompt: {prompt}")
            
            # Call the ComfyUI generation function
            result = generate_image_with_comfyui(prompt, **kwargs)
            
            if result:
                return result
            print(f"Attempt {attempt+1} failed to return a valid URL")
            
        except Exception as e:
            print(f"Error during generation attempt {attempt+1}: {str(e)}")
            import traceback
            traceback.print_exc()
        
        # Only sleep if we're going to retry
        if attempt < max_attempts - 1:
            backoff = 2 ** attempt
            print(f"Retrying in {backoff} seconds...")
            time.sleep(backoff)
    
    print(f"Failed to generate image after {max_attempts} attempts")
    return None


# Example usage:
if __name__ == "__main__":
    # Example prompt
    test_prompt = "A beautiful woman at the beach, wearing a swimsuit"
    
    # Generate the image
    image_url = generate_image(
        prompt=test_prompt,
        comfy_server_url="http://72.70.187.181:50346/",
        workflow_file="/Users/l_y_o/Work/happyface/pseo/flux-nsfw-upload-api.json"
    )
    
    if image_url:
        print(f"Final image URL: {image_url}")
    else:
        print("Image generation failed")
# Out:
# Generation attempt 1/3
# Prompt: A beautiful woman at the beach, wearing a swimsuit
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: 680200b4-76a8-43ea-8459-e863f94928fe
# Waiting for job 680200b4-76a8-43ea-8459-e863f94928fe to complete...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Job 680200b4-76a8-43ea-8459-e863f94928fe not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_7c67daeb-214c-4628-a112-21e4441a08eb.png?
# Final image URL: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_7c67daeb-214c-4628-a112-21e4441a08eb.png?

# %%
with open('/Users/l_y_o/Work/happyface/pseo/ai_girls_types_images.json', 'r') as f:
    types_images = json.load(f)
    print(f"Loaded {len(types_images)} types")
for ai_girl_type in tqdm(ai_girls_types):
    print(f"type {ai_girl_type} not done: {ai_girl_type not in types_images or len(types_images[ai_girl_type]) < 10:}")
# Out:
# Loaded 17 types
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 55072.27it/s]
# type nude girl not done: False
# type sexy girl not done: False
# type hot girl not done: False
# type little girl not done: False
# type teen girl not done: False
# type nn girl not done: False
# type bikini girl not done: False
# type anime girl not done: False
# type tween girl not done: False
# type girls porn not done: False
# type young girl not done: False
# type girl in panties not done: False
# type cute girl not done: False
# type girl in underwear not done: False
# type girls kissing not done: False
# type school girls not done: False
# type asign girls not done: True
# type girl in lingerie not done: True
# type girl satin not done: True
# type muscle girl not done: True
# type beach girl not done: True
# type topless girl not done: True
# type petite girl not done: True
# type pregnant girl not done: True
# type valhalla girl not done: True

# %%
# iter over the types and generate images, gen 6 images for each type
# types_images = {}
for ai_girl_type in tqdm(ai_girls_types):
    if ai_girl_type not in types_images:
        types_images[ai_girl_type] = []

    if ai_girl_type in types_images and len(types_images[ai_girl_type]) >= 10:
        print(f"type {ai_girl_type} already has 10 images")
        continue
    while len(types_images[ai_girl_type]) < 10:
        try:
            image_url = generate_image(
                prompt=ai_girl_type + ", beautiful girl",
                comfy_server_url="http://193.143.121.70:39267/",
                    workflow_file="/Users/l_y_o/Work/happyface/pseo/flux-nsfw-upload-api.json"
                )
            types_images[ai_girl_type].append(image_url)
        except Exception as e:
            print(f"Error generating image for {ai_girl_type}: {str(e)}")
            continue

    # save the types_images
    with open('/Users/l_y_o/Work/happyface/pseo/ai_girls_types_images.json', 'w') as f:
        json.dump(types_images, f)
        print(f"Saved {len(types_images[ai_girl_type])} images for {ai_girl_type}")
# Out:
#   0%|                                                                                                                                                                                                                                                                          | 0/26 [00:00<?, ?it/s]
# type nude girl already has 10 images
# type sexy girl already has 10 images
# type hot girl already has 10 images
# type little girl already has 10 images
# type teen girl already has 10 images
# type nn girl already has 10 images
# type bikini girl already has 10 images
# type anime girl already has 10 images
# type tween girl already has 10 images
# type girls porn already has 10 images
# type young girl already has 10 images
# type girl in panties already has 10 images
# type cute girl already has 10 images
# type girl in underwear already has 10 images
# type girls kissing already has 10 images
# type school girls already has 10 images
# type asign girls already has 10 images
# type girl in lingerie already has 10 images
# type girl satin already has 10 images
# type muscle girl already has 10 images
# type beach girl already has 10 images
# type topless girl already has 10 images
# type petite girl already has 10 images
# type pregnant girl already has 10 images
# type valhalla girl already has 10 images
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: 1df13890-1535-4502-a8f6-503a703bb488
# Waiting for job 1df13890-1535-4502-a8f6-503a703bb488 to complete...
# Job 1df13890-1535-4502-a8f6-503a703bb488 not found in history yet. Waiting...
# Job 1df13890-1535-4502-a8f6-503a703bb488 not found in history yet. Waiting...
# Job 1df13890-1535-4502-a8f6-503a703bb488 not found in history yet. Waiting...
# Job 1df13890-1535-4502-a8f6-503a703bb488 not found in history yet. Waiting...
# Job 1df13890-1535-4502-a8f6-503a703bb488 not found in history yet. Waiting...
# Job 1df13890-1535-4502-a8f6-503a703bb488 not found in history yet. Waiting...
# Job 1df13890-1535-4502-a8f6-503a703bb488 not found in history yet. Waiting...
# Timeout reached after 300 seconds
# Attempt 1 failed to return a valid URL
# Retrying in 1 seconds...
# Generation attempt 2/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: bbcdffc3-6c79-4070-b0ed-dc67dd7b7865
# Waiting for job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 to complete...
# Job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 not found in history yet. Waiting...
# Job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 not found in history yet. Waiting...
# Job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 not found in history yet. Waiting...
# Job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 not found in history yet. Waiting...
# Job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 not found in history yet. Waiting...
# Job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 not found in history yet. Waiting...
# Job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 not found in history yet. Waiting...
# Job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 not found in history yet. Waiting...
# Job bbcdffc3-6c79-4070-b0ed-dc67dd7b7865 not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_e089d793-941c-46d9-b452-971eec54ab53.png?
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: 6cb0592a-e0ab-4737-821a-0952a3bfc91c
# Waiting for job 6cb0592a-e0ab-4737-821a-0952a3bfc91c to complete...
# Job 6cb0592a-e0ab-4737-821a-0952a3bfc91c not found in history yet. Waiting...
# Job 6cb0592a-e0ab-4737-821a-0952a3bfc91c not found in history yet. Waiting...
# Job 6cb0592a-e0ab-4737-821a-0952a3bfc91c not found in history yet. Waiting...
# Job 6cb0592a-e0ab-4737-821a-0952a3bfc91c not found in history yet. Waiting...
# Job 6cb0592a-e0ab-4737-821a-0952a3bfc91c not found in history yet. Waiting...
# Job 6cb0592a-e0ab-4737-821a-0952a3bfc91c not found in history yet. Waiting...
# Job 6cb0592a-e0ab-4737-821a-0952a3bfc91c not found in history yet. Waiting...
# Job 6cb0592a-e0ab-4737-821a-0952a3bfc91c not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_8503741c-9552-48ef-9306-a40e3fc87172.png?
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93
# Waiting for job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 to complete...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Job 3fee2729-6b0d-4195-b6bc-d4a5b8cd1a93 not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_61e10359-2475-4591-bd66-c361de2162ce.png?
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: 29d185c6-b565-41cf-be58-3338b84b302c
# Waiting for job 29d185c6-b565-41cf-be58-3338b84b302c to complete...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Job 29d185c6-b565-41cf-be58-3338b84b302c not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_4db2c8b6-a007-4543-bbc3-2f50ee61bd30.png?
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: ac79564a-0170-47c2-b3dc-c1fd92343c37
# Waiting for job ac79564a-0170-47c2-b3dc-c1fd92343c37 to complete...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Job ac79564a-0170-47c2-b3dc-c1fd92343c37 not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_7ae2402e-53c8-47cf-b59e-63c54e211d87.png?
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: 87b71472-0ec6-45ef-88a4-e32843d9b6cc
# Waiting for job 87b71472-0ec6-45ef-88a4-e32843d9b6cc to complete...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Job 87b71472-0ec6-45ef-88a4-e32843d9b6cc not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_1d4b9754-5bdc-46d4-9be0-668c947a3f13.png?
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: dcc9df7d-bebe-455d-abb4-4de55d4534af
# Waiting for job dcc9df7d-bebe-455d-abb4-4de55d4534af to complete...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Job dcc9df7d-bebe-455d-abb4-4de55d4534af not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_9bb90dea-92ad-435a-b408-5bdd77adf351.png?
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: d7f919cb-cbb3-4ae8-876c-9d9b6b969698
# Waiting for job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 to complete...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Job d7f919cb-cbb3-4ae8-876c-9d9b6b969698 not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_0d03121f-b00f-4601-aedd-060a7c6da8b5.png?
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: 0a3b0ecf-24d1-4848-8801-5805c84fe450
# Waiting for job 0a3b0ecf-24d1-4848-8801-5805c84fe450 to complete...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Job 0a3b0ecf-24d1-4848-8801-5805c84fe450 not found in history yet. Waiting...
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_34bead0a-23f3-4cee-8758-78dc1a56edfc.png?
# Generation attempt 1/3
# Prompt: asian girls, beautiful girl
# Submitting generation job attempt 1/3...
# Successfully submitted job with ID: 7393fd28-b2f4-4613-8707-f0573a3c89f5
# Waiting for job 7393fd28-b2f4-4613-8707-f0573a3c89f5 to complete...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# Job 7393fd28-b2f4-4613-8707-f0573a3c89f5 not found in history yet. Waiting...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [10:56<00:00, 25.24s/it]
# Successfully generated image: https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-girls-gend/comfy_90b5dedc-dda5-4bf1-9073-14aba1e6d0d3.png?
# Saved 10 images for asian girls

# %%
# save the types_images
with open('/Users/l_y_o/Work/happyface/pseo/ai_girls_types_images.json', 'w') as f:
    json.dump(types_images, f)
    print(f"Saved {len(types_images[ai_girl_type])} images for {ai_girl_type}")
# Out:
# Saved 10 images for asian girls

# %%
len(types_images), len(ai_girls_types)
# Out:
# (17, 22)

# %% [markdown]
# # add missing faq dict

# %% [markdown]
# # gen landing contents

# %%
examples = []
with open("/Users/l_y_o/Work/happyface/app/tools/[generator-title]/enhanced_results_with_prompts_nsfw_image_gend.json", "r") as f:
    examples = json.load(f)

landing_keys = ["title", "subtitle", "how_to_use_title", "how_to_step1_title", "how_to_step1_content", "how_to_step2_title", "how_to_step2_content", "how_to_step3_title", "how_to_step3_content", 
                "feature1_title", "feature1_content", "feature2_title", "feature2_content", "feature3_title", "feature3_content", "cta_title", "cta_content", "faq_dict", "title_seo", "description_seo"]

example_prompts = []
for i in range(2,4):
    prompt = ""
    for key in landing_keys:
        if key == "faq_dict" and key not in examples[i]:
            print(f"no faq_dict for {examples[i]['title']}")
            continue
        prompt += "{key}: {value}, ".format(key=key, value=examples[i][key])

    example_prompts.append(prompt)


example_prompts
# Out:
# ['title: AI Milf Generator, subtitle: Easily create your ideal AI generated milf using this AI tool. With this simple MILF generator, you can produce realistic photos in just a few seconds. No technical skills needed—just enter your preferences and let the AI do the work., how_to_use_title: How to use AI Milf Generator:, how_to_step1_title: Describe Your Image, how_to_step1_content: Start by entering a detailed description of the image you want to create in the prompt box. Be clear and specific, including important keywords to help the AI generate the image you envision. For example, you can describe a landscape, a portrait, or an abstract concept. Once you\'re satisfied with your description, click the "Generate" button., how_to_step2_title: Generation Process, how_to_step2_content: After you click "Generate," the AI Image Generator will process your prompt and begin creating your AI generated milf. This may take a few moments, depending on the complexity of your request and the current system load., how_to_step3_title: Download Your Image, how_to_step3_content: When the AI finishes generating your image, it will appear on the screen. You can then download it to your device for personal or commercial use. Share your unique AI-generated creation with others or incorporate it into your projects., feature1_title: Create Your Perfect MILF AI Art, feature1_content: No need to search endlessly for the right image anymore. With our AI MILF generator, you can create custom MILF art that matches your specific preferences. Simply provide a detailed description, and the AI will generate a high-quality image suited to your needs., feature2_title: Simple and User-Friendly, feature2_content: Our AI MILF generator is easy to use for everyone. There\'s no need for technical expertise—just input your description and let the AI do the work. Quickly produce stunning MILF AI images without any fuss., feature3_title: High-Quality Results Every Time, feature3_content: Experience the power of AI in creating detailed and realistic MILF images. Our advanced AI technology guarantees high-quality results that look professional and lifelike. Whether for personal use or creative projects, create the best quality image every time., cta_title: More Than Just a AI Milf Generator, cta_content: BasedLabs isn\'t just an AI Milf Generator. Sure, you can download AI-generated images in seconds, but there\'s a lot more. You can use our built-in video editing app to turn your photos into videos, and even edit audio. It\'s a full-featured professional video editing software that lets you create amazing videos in minutes, without needing any prior experience.  Give BasedLabs a try today and see how AI can enhance your images, videos, and audio!, faq_dict: {\'How can I get started with the AI MILF generator?\': "To get started, visit the generator\'s platform, sign up or log in, and follow the instructions to create your desired images.", \'Does the AI MILF generator cost anything?\': "Pricing details vary depending on the features and usage. Check the platform\'s pricing page for more information.", \'How quickly are images generated?\': \'Images are generated almost instantly, typically within a few seconds, depending on the complexity of your request.\', \'What file types are available for export?\': \'The generator supports multiple file formats including JPEG, PNG, and others commonly used for image sharing and editing.\', \'How is my data kept secure while using the generator?\': \'Your data is kept secure through encryption and adherence to industry-best practices for privacy protection.\'}, title_seo: AI Milf Generator: Create Stunning AI Images, description_seo: Discover the AI Milf Generator to craft stunning, customized AI imagery. Easy-to-use and perfect for creative projects. Try it now!, ',
#  'title: AI Waifu Generator, subtitle: Explore the capabilities of the AI waifu generator, enabling you to bring your ideal anime waifu to life in any pose you can imagine., how_to_use_title: How to use AI Waifu Generator:, how_to_step1_title: Define Your Waifu, how_to_step1_content: Input your idea into the prompt box, using specific keywords to define the style and characteristics of your anime waifu. Once you\'re ready, click the "Generate Images" button to start the process., how_to_step2_title: Wait for Processing, how_to_step2_content: Allow the AI a moment to interpret your description and generate the image. Please be patient during this brief period., how_to_step3_title: Review the Artwork, how_to_step3_content: After the AI completes its task, you can view the detailed artwork based on your concept. This image is yours to use freely, including for commercial purposes., feature1_title: Effortless Waifu Creation, feature1_content: Bring your dream anime waifu to life with our waifu AI generator by simply describing her in words. No art skills required—let our waifu generator AI translate your ideas into stunning artwork that matches your vision perfectly., feature2_title: Customizable Poses, feature2_content: Design your anime waifu in any pose you desire using our anime waifu AI generator. Whether you\'re aiming for something playful, serious, or dynamic, our AI tool can craft the perfect image to suit your needs., feature3_title: Instant Results, feature3_content: Experience the satisfaction of seeing your concept materialize within seconds with our waifu AI art generator. Our powerful waifu generator AI processes your descriptions quickly, providing you with detailed, high-quality images ready for use, including NSFW AI waifu generator options if desired., cta_title: More Than Just an AI Waifu Generator, cta_content: BasedLabs offers a diverse set of AI-powered tools that cater to all your creative needs, beyond just waifu generation. Utilize our advanced AI models for image creation, photo editing, and video transformation to enhance your visual content. Our user-friendly tools are built for efficiency and innovation, supporting professionals, content creators, and anime enthusiasts in reaching new creative heights., faq_dict: {\'Error\': \'Could not extract FAQ content properly\'}, title_seo: AI Waifu Generator - Create Your Perfect Anime Companion, description_seo: Design custom AI waifus with advanced tools. Generate your ideal anime companion with unique features and styles. Try it now!, ']

# %%
# use deep seek to gen landing contents
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [175], in <cell line: 1>()
# ----> 1 examples[0]['faq_dict']
#
# KeyError: 'faq_dict'

# %%
import json
import time
import os
from openai import OpenAI
from typing import Dict, List, Any, Optional
from tqdm import tqdm
import pandas as pd

# Define the types of AI Girls from the notebook
ai_girls_types = [
  'nude girl',
  'sexy girl',
  'hot girl',
  'little girl',
  'teen girl',
  'nn girl',
  'bikini girl',
  'anime girl',
  'tween girl', 
  'girls porn',
  'young girl',
  'girl in panties',
  'cute girl',
  'girl in underwear',
  'girls kissing',
  'school girls',
  'asign girls',
  'girl in lingerie',
  'girl satin',
  'muscle girl',
  'beach girl',
  'topless girl',
  'petite girl',
  'pregnant girl',
  'valhalla girl', 
  'asian girls',
]

# Define landing page keys
landing_keys = [
    "title", "subtitle", "how_to_use_title", "how_to_step1_title", "how_to_step1_content",
    "how_to_step2_title", "how_to_step2_content", "how_to_step3_title", "how_to_step3_content",
    "feature1_title", "feature1_content", "feature2_title", "feature2_content",
    "feature3_title", "feature3_content", "cta_title", "cta_content", "faq_dict",
    "title_seo", "description_seo"
]

# Example landing page content for few-shot learning
example_landing_pages = [
    {
        "title": "AI Milf Generator",
        "subtitle": "Easily create your ideal AI generated milf using this AI tool. With this simple MILF generator, you can produce realistic photos in just a few seconds. No technical skills needed—just enter your preferences and let the AI do the work.",
        "how_to_use_title": "How to use AI Milf Generator:",
        "how_to_step1_title": "Describe Your Image",
        "how_to_step1_content": "Start by entering a detailed description of the image you want to create in the prompt box. Be clear and specific, including important keywords to help the AI generate the image you envision. For example, you can describe a landscape, a portrait, or an abstract concept. Once you're satisfied with your description, click the \"Generate\" button.",
        "how_to_step2_title": "Generation Process",
        "how_to_step2_content": "After you click \"Generate,\" the AI Image Generator will process your prompt and begin creating your AI generated milf. This may take a few moments, depending on the complexity of your request and the current system load.",
        "how_to_step3_title": "Download Your Image",
        "how_to_step3_content": "When the AI finishes generating your image, it will appear on the screen. You can then download it to your device for personal or commercial use. Share your unique AI-generated creation with others or incorporate it into your projects.",
        "feature1_title": "Create Your Perfect MILF AI Art",
        "feature1_content": "No need to search endlessly for the right image anymore. With our AI MILF generator, you can create custom MILF art that matches your specific preferences. Simply provide a detailed description, and the AI will generate a high-quality image suited to your needs.",
        "feature2_title": "Simple and User-Friendly",
        "feature2_content": "Our AI MILF generator is easy to use for everyone. There's no need for technical expertise—just input your description and let the AI do the work. Quickly produce stunning MILF AI images without any fuss.",
        "feature3_title": "High-Quality Results Every Time",
        "feature3_content": "Experience the power of AI in creating detailed and realistic MILF images. Our advanced AI technology guarantees high-quality results that look professional and lifelike. Whether for personal use or creative projects, create the best quality image every time.",
        "cta_title": "More Than Just a AI Milf Generator",
        "cta_content": "BasedLabs isn't just an AI Milf Generator. Sure, you can download AI-generated images in seconds, but there's a lot more. You can use our built-in video editing app to turn your photos into videos, and even edit audio. It's a full-featured professional video editing software that lets you create amazing videos in minutes, without needing any prior experience. Give BasedLabs a try today and see how AI can enhance your images, videos, and audio!",
        "faq_dict": {
            "How can I get started with the AI MILF generator?": "To get started, visit the generator's platform, sign up or log in, and follow the instructions to create your desired images.",
            "Does the AI MILF generator cost anything?": "Pricing details vary depending on the features and usage. Check the platform's pricing page for more information.",
            "How quickly are images generated?": "Images are generated almost instantly, typically within a few seconds, depending on the complexity of your request.",
            "What file types are available for export?": "The generator supports multiple file formats including JPEG, PNG, and others commonly used for image sharing and editing.",
            "How is my data kept secure while using the generator?": "Your data is kept secure through encryption and adherence to industry-best practices for privacy protection."
        },
        "title_seo": "AI Milf Generator: Create Stunning AI Images",
        "description_seo": "Discover the AI Milf Generator to craft stunning, customized AI imagery. Easy-to-use and perfect for creative projects. Try it now!"
    },
    {
        "title": "AI Waifu Generator",
        "subtitle": "Explore the capabilities of the AI waifu generator, enabling you to bring your ideal anime waifu to life in any pose you can imagine.",
        "how_to_use_title": "How to use AI Waifu Generator:",
        "how_to_step1_title": "Define Your Waifu",
        "how_to_step1_content": "Input your idea into the prompt box, using specific keywords to define the style and characteristics of your anime waifu. Once you're ready, click the \"Generate Images\" button to start the process.",
        "how_to_step2_title": "Wait for Processing",
        "how_to_step2_content": "Allow the AI a moment to interpret your description and generate the image. Please be patient during this brief period.",
        "how_to_step3_title": "Review the Artwork",
        "how_to_step3_content": "After the AI completes its task, you can view the detailed artwork based on your concept. This image is yours to use freely, including for commercial purposes.",
        "feature1_title": "Effortless Waifu Creation",
        "feature1_content": "Bring your dream anime waifu to life with our waifu AI generator by simply describing her in words. No art skills required—let our waifu generator AI translate your ideas into stunning artwork that matches your vision perfectly.",
        "feature2_title": "Customizable Poses",
        "feature2_content": "Design your anime waifu in any pose you desire using our anime waifu AI generator. Whether you're aiming for something playful, serious, or dynamic, our AI tool can craft the perfect image to suit your needs.",
        "feature3_title": "Instant Results",
        "feature3_content": "Experience the satisfaction of seeing your concept materialize within seconds with our waifu AI art generator. Our powerful waifu generator AI processes your descriptions quickly, providing you with detailed, high-quality images ready for use, including NSFW AI waifu generator options if desired.",
        "cta_title": "More Than Just an AI Waifu Generator",
        "cta_content": "BasedLabs offers a diverse set of AI-powered tools that cater to all your creative needs, beyond just waifu generation. Utilize our advanced AI models for image creation, photo editing, and video transformation to enhance your visual content. Our user-friendly tools are built for efficiency and innovation, supporting professionals, content creators, and anime enthusiasts in reaching new creative heights.",
        "faq_dict": {
            "What is an AI Waifu Generator?": "An AI Waifu Generator is an advanced AI tool that creates customized anime-style character images based on user descriptions, allowing fans to bring their ideal waifu concepts to life with remarkable detail and accuracy.",
            "Can I customize my waifu's appearance?": "Yes, you can fully customize your waifu's appearance by providing detailed descriptions of characteristics like hair color, eye shape, outfit style, pose, and background elements in your generation prompt.",
            "How realistic do the generated waifus look?": "The generated waifus can look remarkably realistic within anime aesthetics, with high-quality rendering of features, textures, and lighting that create visually appealing and cohesive character designs.",
            "Can I use these images commercially?": "Most AI Waifu Generators allow for commercial use of generated images, though specific terms may vary by platform. Always check the terms of service for the particular tool you're using.",
            "Is the waifu generator suitable for beginners?": "Absolutely. The waifu generator features an intuitive interface designed for users of all experience levels. No technical or artistic expertise is required to create stunning anime character images."
        },
        "title_seo": "AI Waifu Generator - Create Your Perfect Anime Companion",
        "description_seo": "Design custom AI waifus with advanced tools. Generate your ideal anime companion with unique features and styles. Try it now!"
    
    }
]

def setup_perplexity_client(api_key: str) -> OpenAI:
    """
    Set up the OpenAI client to use with the Perplexity API.
    
    Args:
        api_key: Perplexity API key
        
    Returns:
        OpenAI client configured for Perplexity
    """
    return OpenAI(
        api_key=api_key,
        base_url="https://api.perplexity.ai"
    )

def create_landing_page_prompt(girl_type: str, examples: List[Dict[str, Any]]) -> str:
    """
    Create a prompt for generating landing page content for a specific type of AI girl.
    
    Args:
        girl_type: The type of AI girl (e.g., "nude girl", "anime girl")
        examples: List of example landing pages for few-shot learning
        
    Returns:
        A string containing the prompt for the model
    """
    # Convert examples to a readable format for few-shot learning
    example_text = json.dumps(examples, indent=2)
    
    prompt = f"""Generate a complete landing page content for an "AI {girl_type.title()} Generator" website. 
    
The landing page should include professional marketing content that focuses on the AI image generation capabilities.
The tone should be professional and appeal to users interested in AI image generation technology.

The landing page should include the following sections:
1. Title and subtitle
2. How to use the generator (with 3 steps)
3. Feature highlights (3 features)
4. Call to action
5. FAQ (5 questions and answers)
6. SEO optimized title and description

Here are examples of landing pages for similar AI generators to use as reference:
{example_text}

Return the content as a JSON object with the following keys:
{json.dumps(landing_keys, indent=2)}

For the faq_dict, provide a dictionary with 5 question-answer pairs.

For title_seo, create an SEO-optimized title tag that includes keywords related to the AI generator type, with a maximum of 60 characters.

For description_seo, create a compelling meta description that summarizes the tool's purpose and benefits, with a maximum of 160 characters.

Make sure all content is professional, tasteful, and focuses on the AI technology's capabilities without being explicit, even if the theme might suggest adult content.
"""
    return prompt

def generate_landing_page(client: OpenAI, girl_type: str, examples: List[Dict[str, Any]], 
                         model: str = "r1-1776", max_retries: int = 3) -> Optional[Dict[str, Any]]:
    """
    Generate landing page content using the Perplexity API.
    
    Args:
        client: OpenAI client configured for Perplexity
        girl_type: The type of AI girl
        examples: Example landing pages for few-shot learning
        model: Model to use for generation
        max_retries: Number of retries in case of errors
        
    Returns:
        Dictionary containing the landing page content, or None if generation failed
    """
    prompt = create_landing_page_prompt(girl_type, examples)
    
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model=model,
                messages=[
                    {"role": "system", "content": "You are a professional copywriter specializing in creating marketing content for AI image generation websites."},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.7,
                max_tokens=3000,
            )
            
            content = response.choices[0].message.content
            
            # Parse the JSON response
            try:
                # Extract JSON content if not already properly formatted
                if not content.strip().startswith('{'):
                    # Try to find JSON in the response
                    json_start = content.find('{')
                    json_end = content.rfind('}') + 1
                    if json_start >= 0 and json_end > json_start:
                        content = content[json_start:json_end]
                
                result = json.loads(content)
                return result
            except json.JSONDecodeError as e:
                print(f"Error parsing JSON for {girl_type}: {e}")
                print(f"Raw content: {content}")
                
                if attempt < max_retries - 1:
                    print(f"Retrying ({attempt+1}/{max_retries})...")
                    time.sleep(2)
                else:
                    return {"error": "Failed to parse JSON", "raw_content": content}
                
        except Exception as e:
            print(f"Error generating content for {girl_type}: {e}")
            if attempt < max_retries - 1:
                print(f"Retrying ({attempt+1}/{max_retries})...")
                time.sleep(2)
    
    return None

def main(results):
    """
    Main function to generate landing pages for all AI girl types.
    """
    # Get API key from environment or prompt user
    api_key = os.environ.get("PERPLEXITY_API_KEY")
    if not api_key:
        api_key = input("Enter your Perplexity API key: ")
    
    # Set up the client
    client = setup_perplexity_client(api_key)
    
    # Initialize results storage
    # results = {}
    
    # Generate landing pages for each type
    for girl_type in tqdm(ai_girls_types, desc="Generating landing pages"):
        if girl_type in results:
            print(f"skipping {girl_type} because it already exists")
            continue
        print(f"\nGenerating landing page for: {girl_type}")
        landing_page = generate_landing_page(client, girl_type, example_landing_pages)
        
        if landing_page:
            results[girl_type] = landing_page
            print(f"Successfully generated content for {girl_type}")
        else:
            print(f"Failed to generate content for {girl_type}")
    
    # Save the results to a JSON file
    with open("ai_girls_landing_pages.json", "w") as f:
        json.dump(results, f, indent=2)
    
    print(f"\nGenerated {len(results)} landing pages out of {len(ai_girls_types)} types")
    print("Results saved to ai_girls_landing_pages.json")
    
    # Also convert to a DataFrame for easier viewing
    df_rows = []
    for girl_type, content in results.items():
        if isinstance(content, dict) and "error" not in content:
            row = {"type": girl_type}
            for key in landing_keys:
                if key == "faq_dict" and isinstance(content.get(key), dict):
                    row[key] = json.dumps(content.get(key))
                else:
                    row[key] = content.get(key)
            df_rows.append(row)
    
    if df_rows:
        df = pd.DataFrame(df_rows)
        df.to_csv("ai_girls_landing_pages.csv", index=False)
        print("CSV file also created: ai_girls_landing_pages.csv")

# %%
results
# Out:
# [{'title': 'DnD AI Art Generator',
#   'subtitle': 'Try our DnD AI art generator to bring your DnD characters to life. Experience the world of Dungeons & Dragons as your unique creations are visualized in stunning detail.',
#   'how_to_use_title': 'How to use DnD AI Art Generator:',
#   'how_to_step1_image': 'https://cdn.basedlabs.ai/9f9b8f90-1323-11ef-a1ff-372c484d0bb7.png',
#   'how_to_step2_image': 'https://cdn.basedlabs.ai/a5ae6e70-1323-11ef-a1ff-372c484d0bb7.png',
#   'how_to_step3_image': 'https://cdn.basedlabs.ai/5e354960-770f-11ef-be95-bdc3ce781d17.png',
#   'how_to_step1_title': 'Enter Your Prompt',
#   'how_to_step2_title': 'Let the AI Work',
#   'how_to_step3_title': 'Explore Your Artwork',
#   'how_to_step1_content': 'Begin by entering a description of your character in the prompt area. You can include keywords to specify the style and mood. Then, click the "Create Images" button.',
#   'how_to_step2_content': 'Wait a couple seconds for the AI to interpret your text and generate an image. Our advanced text-to-image technology will bring your description to life.',
#   'how_to_step3_content': 'Once done, take a moment to enjoy your unique creation. Use your artwork as you wish, with the option to sell it if desired.',
#   'feature1_title': 'Create Unique DnD Characters',
#   'feature1_content': 'Turn your descriptions into detailed DnD characters with ease using our AI art generator DnD tool. Our dnd character art AI generator transforms your text prompts into high-quality images, bringing your Dungeons & Dragons ideas to life.',
#   'feature1_image': 'https://cdn.basedlabs.ai/8569a4d0-7710-11ef-9722-4b74e95790ce.mp4',
#   'feature2_title': 'Explore Random Fantasy Characters',
#   'feature2_content': 'Not sure which DnD character to create? Let our AI DnD art generator surprise you with a random character generation. Just enter "DnD character" as a prompt and select "None." From noble elves to powerful wizards, see the AI bring diverse characters to life.',
#   'feature2_image': 'https://cdn.basedlabs.ai/ccbc2880-7710-11ef-be95-bdc3ce781d17.mp4',
#   'feature3_title': 'Train Custom AI Models for DnD',
#   'feature3_content': 'Our platform lets you train custom AI image models tailored to your needs. Simply upload 5-20 images, and the dnd AI art generator free tool will learn your style. Use this feature to create unique DnD characters or scenes that match your vision precisely.',
#   'feature3_image': 'https://cdn.basedlabs.ai/41f50220-7711-11ef-ba2c-f3a40ae1a573.mp4',
#   'faq': '<h2 class="text-2xl font-bold leading-10 tracking-tight text-zinc-100">Frequently asked questions</h2><dl class="mt-10 space-y-6 divide-y divide-white/10"><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rjam7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">What is the best AI art generator for DnD?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rlam7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">How do I start using the Basedlabs AI art generator DnD tool?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rnam7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">Can I generate random DnD characters with the Basedlabs AI DnD art generator?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rpam7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">How many images do I need to upload to train a custom AI model on Basedlabs?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rram7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">Is the Basedlabs DnD AI art generator free to use?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div></dl>',
#   'cta_title': 'More Than Just a DnD AI Art Generator',
#   'cta_content': "Our AI-powered platform provides more than just a DnD AI Art Generator. Discover our range of creative tools for image generation, photo manipulation, and video transformation, all designed to enhance your visual content. Whether you're a professional artist or a content creator, our user-friendly tools help you expand your creative possibilities and bring your ideas to life.",
#   'how_to_step1_image_description': 'A software interface for generating AI images featuring a prompt about a neon-lit city street and a woman in dark clothes.',
#   'how_to_step2_image_description': 'The image shows a blurred interface of an AI image generation tool. A green hourglass icon is displayed with the text "Generating…" beneath it. Progress is at 40%, and the status reads "Position in queue: Processing."',
#   'how_to_step3_image_description': 'A medieval character wears a detailed leather armor with fur accents, a red cape, and ornate straps. Flames and blurred ruins form the dramatic background.',
#   'feature1_image_description': 'A warrior adorned in ornate, dark metallic armor with golden accents, carrying a sword on her back. She stands amidst a dramatic, cloudy and rocky landscape, with long flowing hair and a red cape.',
#   'feature2_image_description': 'A warrior dressed in medieval-inspired attire stands in a snowy forest. He wears a red cloak with fur trim, leather armor adorned with various metallic details, and gloves. Holding a large battle axe, his outfit suggests a historical or fantasy setting. Snow gently falls around him, creating a cold, atmospheric scene.',
#   'feature3_image_description': 'A lone warrior stands in a desert at sunset, facing a futuristic pod-like structure. Sparse vegetation surrounds them. One person appears inside the pod’s window.',
#   'title_rewrite': 'AI-Powered DnD Art',
#   'subtitle_rewrite': 'Unleash your imagination with our DnD AI art generator—turn your Dungeons & Dragons characters into breathtaking visuals with ease. Witness your creations come alive in extraordinary detail.',
#   'how_to_use_title_rewrite': 'Using the DnD AI Art Generator:',
#   'how_to_step1_title_rewrite': 'Input Your Idea',
#   'how_to_step1_content_rewrite': '**Step 1: Craft Your Character Vision**  \nStart by typing a detailed description of your character into the prompt box. Feel free to include key terms that capture the personality, vibe, or atmosphere you want to convey. Once your description is ready, bring your idea to life by clicking the "Create Images" button. It’s that simple to take the first step toward your perfect character design!',
#   'how_to_step2_title_rewrite': 'Watch AI in Action',
#   'how_to_step2_content_rewrite': 'Give the AI a moment to work its magic! In just a few seconds, our cutting-edge text-to-image technology will analyze your input and craft a stunning visual representation of your description. Watch as your words transform into a captivating image before your eyes.',
#   'how_to_step3_title_rewrite': 'Discover Your Masterpiece',
#   'how_to_step3_content_rewrite': "Step 3: Admire and Share Your Masterpiece  \n\nCongratulations! You've brought your vision to life. Take a moment to truly appreciate the one-of-a-kind piece you've created. Whether you choose to display it proudly, gift it to someone special, or even turn your creativity into profit by selling it—the possibilities are endless. Your artwork is yours to cherish, share, or monetize as you see fit.",
#   'feature1_title_rewrite': 'Craft One-of-a-Kind DnD Heroes',
#   'feature1_content_rewrite': "Bring your Dungeons & Dragons visions to life effortlessly with our cutting-edge AI-powered DnD character art tool. Simply describe your character, and watch as your words transform into stunning, high-resolution visuals. Whether you're crafting a brave hero or a sinister villain, our generator turns your imagination into captivating artwork in just moments.",
#   'feature2_title_rewrite': 'Discover Unique Fantasy Personas',
#   'feature2_content_rewrite': '**Discover Your Next Adventurer with a Click**  \nStuck on what kind of DnD character to create? Let the magic of our AI DnD art generator guide your imagination. Simply type "DnD character" into the prompt field and choose "None" for a surprise that’s as unique as your next campaign. Whether it’s a valiant elf or a spellbinding wizard, watch as the AI crafts characters bursting with personality and flair.',
#   'feature3_title_rewrite': 'Build Tailored AI for Your DnD',
#   'feature3_content_rewrite': "**Bring Your Imagination to Life with Custom AI Image Models**  \nTurn your creative vision into reality with our intuitive platform, designed to help you craft AI image models that are as unique as your ideas. Whether you're dreaming up dynamic DnD characters or immersive fantasy scenes, our tool makes it effortless. Just upload 5 to 20 images that capture your desired style, and our free AI art generator will adapt to match your artistic flair. Create visuals that truly reflect your imagination, down to the finest detail.",
#   'faq_rewrite': '```html\n<h2 class="text-2xl font-bold leading-10 tracking-tight text-zinc-100">Common Questions</h2>\n<dl class="mt-10 space-y-6 divide-y divide-white/10">\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rjam7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">Which AI tool works best for creating DnD-themed artwork?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      </button>\n    </dt>\n  </div>\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rlam7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">What steps should I follow to begin using Basedlabs\' AI DnD tool?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      </button>\n    </dt>\n  </div>\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rnam7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">Does the Basedlabs AI tool allow me to create random DnD characters?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      </button>\n    </dt>\n  </div>\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rpam7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">How many images are necessary to train a custom AI model with Basedlabs?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      </button>\n    </dt>\n  </div>\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rram7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">Is there a cost to use the Basedlabs AI generator for DnD art?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      < ...
#   'cta_title_rewrite': 'Beyond a Simple DnD AI Art Tool',
#   'cta_content_rewrite': 'Unleash your creative potential with our cutting-edge, AI-driven platform. Beyond a simple DnD AI Art Generator, we offer an entire suite of innovative tools tailored for image creation, photo editing, and video transformation. Crafted to elevate your visual storytelling, our features are perfect for professional artists and passionate creators alike. With intuitive design and powerful capabilities, you’ll have everything you need to turn your bold ideas into captivating works of art. Dive in and redefine what’s possible—your imagination is the only limit.',
#   'main_image': 'https://cdn.basedlabs.ai/6c426f50-7710-11ef-9465-5f4dab623686.jpg',
#   'main_image_description': 'A fantasy warrior stands in an ancient stone corridor, clad in ornate armor with fur accents, a red cape, and holding a large, intricately designed battle axe.',
#   'how_to_step1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/53f43e3d-275a-42b1-9248-77734a0f1aaa.png?',
#   'how_to_step2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/f74123ca-8103-4764-af93-519d09c85d0a.png?',
#   'how_to_step3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/comfy_147c05f2-48bf-417d-9e81-587d8a4614c6.png?',
#   'feature1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/comfy_ff82be25-3fb6-4d68-86c7-172885fcadd1.png?',
#   'feature2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/comfy_88905761-4dee-4470-9bf2-22e5a41898e9.png?',
#   'feature3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/comfy_79e5e83b-c90d-42aa-9865-97996c10a3e2.png?',
#   'main_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/comfy_3d8c30d1-4b7b-4988-8748-1e9c822b66b2.png?',
#   'title_seo': 'DnD AI Art Generator: Create Stunning Fantasy Artwork',
#   'description_seo': 'Unleash creativity with the DnD AI Art Generator. Craft epic fantasy characters, scenes, and more in seconds. Perfect for campaigns and inspiration!',
#   'faq_dict': {'Which AI tool works best for creating DnD-themed artwork?': "Basedlabs' AI tool is specifically designed for generating DnD-themed artwork, making it a great choice for this purpose.",
#    "What steps should I follow to begin using Basedlabs' AI DnD tool?": 'To start using the Basedlabs AI DnD tool, you should create an account, log in, and follow the tutorials provided on their platform to understand how to use the features effectively.',
#    'Does the Basedlabs AI tool allow me to create random DnD characters?': 'Yes, the Basedlabs AI tool includes features for generating random DnD characters based on user preferences or randomization options.',
#    'How many images are necessary to train a custom AI model with Basedlabs?': 'Typically, Basedlabs recommends using a dataset of at least 50–100 high-quality images for training a custom AI model effectively.',
#    'Is there a cost to use the Basedlabs AI generator for DnD art?': "Basedlabs' AI generator may have costs associated depending on the subscription plan or usage limits. Check their pricing page for specific details."}},
#  {'title': 'Anime PFP Maker',
#   'subtitle': "Design your own Anime PFP with BasedLabs' easy-to-use online tool. Transform photos or text descriptions into unique animated avatars, giving your social media profiles a fresh, eye-catching look.",
#   'how_to_use_title': 'How to use Anime PFP Maker:',
#   'how_to_step1_image': 'https://cdn.basedlabs.ai/ebdbef90-1322-11ef-aa68-afe163f649bc.png',
#   'how_to_step2_image': 'https://cdn.basedlabs.ai/f4545cc0-1322-11ef-8db3-a768c4e6dce1.png',
#   'how_to_step3_image': 'https://cdn.basedlabs.ai/d74dbb70-1328-11ef-b81e-2b6886afc8ed.png',
#   'how_to_step1_title': 'Input Details and Choose Style',
#   'how_to_step2_title': 'Generate Your Anime PFP',
#   'how_to_step3_title': 'Preview and Download',
#   'how_to_step1_content': "Describe your desired anime character's features, including gender, hair color, eye color, and any specific traits. Select your preferred anime art style.",
#   'how_to_step2_content': 'Click "Generate" to create your anime profile picture based on your description. You can adjust elements like expressions or backgrounds if the tool offers these options.',
#   'how_to_step3_content': 'Review your generated Anime PFP. If you\'re happy with the result, click "Download" to save your new anime-style profile picture.',
#   'feature1_title': 'Tailored Character Design',
#   'feature1_content': "Create your ideal pfp anime style, whether you're after an anime girl PFP or anime boy PFP. Our tool offers options for cute anime girl PFPs, cool anime PFPs, and everything in between.",
#   'feature1_image': 'https://cdn.basedlabs.ai/fc4eac50-6e53-11ef-8b47-479ac6437ec7.mp4',
#   'feature2_title': 'Expressive Avatars',
#   'feature2_content': 'Match your mood with diverse styles - from aesthetic anime PFPs to sad anime PFPs. Design anime pfp girls or boys that truly represent you online.',
#   'feature2_image': 'https://cdn.basedlabs.ai/fecb08e0-6e51-11ef-aa13-012aa003943e.mp4',
#   'feature3_title': 'Easy Customization',
#   'feature3_content': 'Quickly craft a cute anime PFP or design matching anime PFPs with friends. Our user-friendly tool makes creating your perfect anime profile picture simple and fun.',
#   'feature3_image': 'https://cdn.basedlabs.ai/5013d540-6e54-11ef-b925-b7146fb3cfbc.mp4',
#   'faq': '<h2 class="text-2xl font-bold leading-10 tracking-tight text-zinc-100">Frequently asked questions</h2><dl class="mt-10 space-y-6 divide-y divide-white/10"></dl>',
#   'cta_title': 'More Than Just AI Generated Anime PFPs',
#   'cta_content': "Our AI-powered platform offers more than just Anime PFPs. Create unique characters, custom backgrounds, and entire scenes for your creative projects. Whether you're working on games, animations, or films, our intuitive tools help bring your visual concepts to life. Our advanced AI simplifies the process of turning ideas into stunning, usable artwork.",
#   'how_to_step1_image_description': 'A UI screen of an image-generation tool is displayed. The selected model is "RealVisXL V4.0" with upscaling disabled. The prompt specifies a "city street, neon, fog, volumetric, closeup portrait photo of a young woman in dark clothes." Options include aspect ratios, image count sliders, and an "Open in Editor" button.',
#   'how_to_step2_image_description': 'A user interface shows an AI image generation tool processing at 40%. A green hourglass icon and "Generating..." text are centered.',
#   'how_to_step3_image_description': 'A serene setting with vibrant green foliage and blue flowers. A figure in a light-colored outfit featuring blue accents sits amidst the greenery.',
#   'feature1_image_description': 'A person with shaggy hair wearing a red open shirt over a black top is outdoors under a blue sky with scattered clouds and falling autumn leaves.',
#   'feature2_image_description': 'A cyberpunk-inspired aesthetic showcasing neon lights. The subject has dark hair tied up, glowing hoop earrings, a choker with embedded LEDs, and tattoos on the neck.',
#   'feature3_image_description': 'A person with tattooed arms holds a futuristic weapon emitting red light. Their armored shoulder pads feature skull motifs, with glowing red accents. The background is a misty, post-apocalyptic setting.',
#   'title_rewrite': 'Create Anime Avatars',
#   'subtitle_rewrite': 'Create your dream Anime PFP effortlessly with BasedLabs. Turn your photos or text descriptions into custom animated avatars that make your social media profiles stand out.',
#   'how_to_use_title_rewrite': 'Using Anime PFP Maker:',
#   'how_to_step1_title_rewrite': 'Enter Info & Select Design',
#   'how_to_step1_content_rewrite': 'Start by painting a vivid picture of your dream anime character. Share the details that bring them to life—whether it’s their gender, the shade of their hair, the sparkle in their eyes, or any unique traits that set them apart. Then, take it a step further by choosing the anime art style that resonates most with your vision. From soft and whimsical to bold and dynamic, this is your chance to shape your character exactly as you’ve imagined.',
#   'how_to_step2_title_rewrite': 'Create Your Anime Avatar',
#   'how_to_step2_content_rewrite': '**Step 2: Bring Your Anime Avatar to Life**  \nHit the "Generate" button to transform your description into a unique anime profile picture! Watch as your vision comes to life, crafted with precision and creativity. Depending on the features available, you may have the option to tweak details like facial expressions or background elements, giving you the freedom to customize your avatar to perfection.',
#   'how_to_step3_title_rewrite': 'View and Save',
#   'how_to_step3_content_rewrite': 'Take a moment to admire your custom Anime PFP! If it perfectly captures your style and personality, simply hit the "Download" button to save your one-of-a-kind anime-inspired profile picture. It’s ready to enhance your online presence in just a click!',
#   'feature1_title_rewrite': 'Custom Crafted Characters',
#   'feature1_content_rewrite': "Design the perfect anime-inspired profile picture that truly captures your style. Whether you're envisioning a charming anime girl PFP or a striking anime boy PFP, our platform has you covered. From adorable and playful designs to bold and edgy looks, explore endless possibilities to craft a PFP that matches your vibe.",
#   'feature2_title_rewrite': 'Dynamic Personas',
#   'feature2_content_rewrite': "**Express Your Vibe with Unique Styles**  \nWhether you're feeling introspective or playful, there's a perfect anime PFP to capture your essence. Explore a variety of captivating options, from dreamy aesthetic designs to emotive, sad anime profiles. Create an anime PFP—be it a charming girl or a bold boy—that reflects your personality and makes your online presence truly unforgettable.",
#   'feature3_title_rewrite': 'Seamless Personalization',
#   'feature3_content_rewrite': 'Effortlessly design an adorable anime PFP or create perfectly matched anime profile pictures with your friends. With our intuitive and easy-to-use tool, bringing your ideal anime avatar to life has never been more enjoyable or straightforward!',
#   'faq_rewrite': '```html\n<h2 class="text-2xl font-bold leading-10 tracking-tight text-zinc-100">Common Questions Answered</h2><dl class="mt-10 space-y-6 divide-y divide-white/10"></dl>\n```',
#   'cta_title_rewrite': 'Beyond AI: Unique Anime PFPs Tailored',
#   'cta_content_rewrite': 'Unleash your creativity with the ultimate AI-driven design platform! Dive into a world where you can craft one-of-a-kind Anime profile pictures, original characters, immersive backgrounds, and even complete scenes tailored to your vision. Perfect for game developers, animators, and filmmakers alike, our user-friendly tools empower you to transform your imagination into breathtaking visuals. Powered by cutting-edge AI technology, we take the complexity out of creating, making it easier than ever to turn your ideas into professional-grade artwork.',
#   'main_image': 'https://cdn.basedlabs.ai/7bb01420-6e54-11ef-9280-afb267ae9b6c.jpg',
#   'main_image_description': 'A character in a red shirt holding a gun while wearing a straw hat, set against a warm, dynamic background.',
#   'how_to_step1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/91da26b7-0a26-49f3-83ed-f0c49214346f.png?',
#   'how_to_step2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/ad079b47-27fb-4c14-945e-1773b47c6edf.png?',
#   'how_to_step3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/2252c97f-9092-4031-8ddc-469ab7203940.png?',
#   'feature1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/e947f42d-74c6-4d92-9860-4c731458d730.png?',
#   'feature2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/2ef34d74-f6f1-4f5a-afdf-1a8ef74e8cb5.png?',
#   'feature3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/comfy_743a90e0-710a-4c28-b232-85a24a461d04.png?',
#   'main_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/comfy_f77e5071-d86e-4884-9c93-8c2196075337.png?',
#   'title_seo': 'Create Stunning Anime PFPs Online',
#   'description_seo': 'Design unique anime profile pictures effortlessly with our free Anime PFP Maker. Customize and download your PFP in seconds!',
#   'faq_dict': {'Common Questions Answered': 'No questions or answers were provided in the given content. Please provide additional details or questions to be addressed.'}},
#  {'title': 'AI Image Extender',
#   'subtitle': 'Use our AI image extender to make images bigger by describing what you want to add.',
#   'how_to_use_title': 'How to use AI Image Extender:',
#   'how_to_step1_image': 'https://cdn.basedlabs.ai/a0546a30-1321-11ef-b148-19538f2665f2.png',
#   'how_to_step2_image': 'https://cdn.basedlabs.ai/a6b20db0-1321-11ef-b148-19538f2665f2.png',
#   'how_to_step3_image': 'https://cdn.basedlabs.ai/ad8f1a60-1321-11ef-a232-8baed1997a3d.png',
#   'how_to_step1_title': 'Generate or upload image',
#   'how_to_step2_title': 'Extend image with our tools',
#   'how_to_step3_title': 'Click generate',
#   'how_to_step1_content': 'Start by either creating a new image with our AI or uploading one from your device. Ensure your initial image is high quality for the best extension results.',
#   'how_to_step2_content': "Employ our AI-powered tools to widen your image's canvas while preserving its integrity. Choose the dimensions to extend, and our system will intelligently fill in the new space.",
#   'how_to_step3_content': "After setting up your image for expansion, press the 'Magic Expand' button. Our AI will extend your image and present you with the new image.",
#   'feature1_title': 'Generative Image Resizing',
#   'feature1_content': 'Effortlessly convert portraits to landscapes and vice versa, ensuring your images perfectly fit any social media platform without leaving empty spaces.',
#   'feature1_image': 'https://cdn.basedlabs.ai/b85aed70-1321-11ef-a232-8baed1997a3d.png',
#   'feature2_title': 'AI-Powered Image Enhancement',
#   'feature2_content': 'Enhance image quality effortlessly with BasedLabs AI Photo Enhancer. Access over 100 editing tools and improve your images with a single click, without manual adjustments.',
#   'feature2_image': 'https://cdn.basedlabs.ai/bf229d60-1321-11ef-8db3-a768c4e6dce1.png',
#   'feature3_title': 'Aspect Ratio Adjustment Presets',
#   'feature3_content': 'Easily resize images to any aspect ratio, from 9:16 to 4:5, without stretching or quality loss. Ideal for adapting to various social media formats like YouTube, Instagram Reels, and more.',
#   'feature3_image': 'https://cdn.basedlabs.ai/c6525df0-1321-11ef-b422-e9e0f1439998.png',
#   'faq': '<h2 class="text-2xl font-bold leading-10 tracking-tight text-zinc-100">Frequently asked questions</h2><dl class="mt-10 space-y-6 divide-y divide-white/10"><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rjam7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">What is an AI image extender?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rlam7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">How does the AI Image Extender work?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rnam7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">What image formats are supported?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rpam7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">Is there a limit to how much an image can be extended?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rram7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">Can the AI Image Extender handle different aspect ratios?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></span></button></dt></div><div class="pt-6" data-headlessui-state=""><dt><button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rtam7c6:" type="button" aria-expanded="false" data-headlessui-state=""><span class="text-base font-semibold leading-7">Is the AI Image Extender free to use?</span><span class="ml-6 flex h-7 items-center"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6"><path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path></svg></sp ...
#   'cta_title': 'More than an AI Image Extender',
#   'cta_content': "BasedLabs offers more than just AI-driven image extension capabilities. With this tool, you can seamlessly expand your images to fit various formats, perfect for social media or professional use. But that's not all – BasedLabs also includes a comprehensive suite of multimedia editing tools. Create and edit videos using your extended images and much more. This user-friendly platform is designed for both beginners and professionals, enabling stunning video creation in minutes. Utilize our ready-to-use user prompts for business or personal projects. Discover the versatility and power of AI with BasedLabs for all your image and video!",
#   'how_to_step1_image_description': 'A photo with a pastel gradient background featuring a cropped image of a person outdoors, with buildings, trees, and parked cars in the backdrop.',
#   'how_to_step2_image_description': 'A person with long wavy brown hair tied in a ponytail stands outdoors. The background shows a street with a wooden storefront, trees, and buildings.',
#   'how_to_step3_image_description': 'A woman stands outdoors with a ponytail, surrounded by buildings, trees, and parked cars. The image features a "Magic Expand" tool selection.',
#   'feature1_image_description': 'The image shows a cute cat wearing a red jacket and cap, standing confidently in a forest-like setting. It is presented in two formats: square for Instagram (1:1) and vertical for TikTok (16:9).',
#   'feature2_image_description': 'The image shows a side-by-side comparison of a car in a cyberpunk cityscape. The left side is blurry, while the right side is sharper with enhanced lighting, showcasing futuristic buildings and glowing taillights. Text reads "Magic Enhance."',
#   'feature3_image_description': 'A skeleton wearing headphones sits by a window, overlaid with cropping aspect ratio options and a "Magic Expand" button on a gradient background.',
#   'title_rewrite': 'Extend Your Images',
#   'subtitle_rewrite': "Expand your images effortlessly with AI—just describe what you'd like to see added.",
#   'how_to_use_title_rewrite': 'Using the AI Image Extender:',
#   'how_to_step1_title_rewrite': 'Create or Import Visuals',
#   'how_to_step1_content_rewrite': "Begin by choosing how you'd like to get started: let our cutting-edge AI generate a brand-new image for you, or simply upload a favorite photo straight from your device. For the most seamless and stunning results, we recommend starting with a crisp, high-resolution image that truly shines.",
#   'how_to_step2_title_rewrite': 'Expand visuals effortlessly',
#   'how_to_step2_content_rewrite': "**Expand Your Vision with Intelligent Precision**  \nUnlock endless creative possibilities by extending the boundaries of your images effortlessly. With our advanced AI-driven technology, you can expand your canvas to fit your unique vision while maintaining flawless continuity. Simply select the dimensions you'd like to add, and let our system seamlessly blend new content into the extended space—perfectly aligned and true to your original masterpiece.",
#   'how_to_step3_title_rewrite': 'Generate results',
#   'how_to_step3_content_rewrite': "Once your image is ready for enhancement, simply click the ‘Magic Expand’ button. In just moments, our advanced AI technology will seamlessly stretch the boundaries of your image, unveiling a beautifully extended version that's ready to impress.",
#   'feature1_title_rewrite': 'Adaptive Image Scaling',
#   'feature1_content_rewrite': 'Seamlessly transform portrait photos into stunning landscapes—or the other way around. Tailor your images to flawlessly match any social media platform, eliminating awkward gaps or empty spaces for a polished, professional look every time.',
#   'feature2_title_rewrite': 'Smart Image Optimization Tool',
#   'feature2_content_rewrite': '**Transform Your Photos Like Never Before**  \nUnlock the power of BasedLabs AI Photo Enhancer to elevate your images in seconds. Say goodbye to tedious edits—with over 100 advanced tools at your fingertips, you can refine every detail or simply let our one-click technology do the work for you. Effortless perfection is just a click away.',
#   'feature3_title_rewrite': 'Preset Options for Aspect Ratios',
#   'feature3_content_rewrite': 'Effortlessly adjust your images to fit any aspect ratio—whether it’s 9:16, 4:5, or anything in between—without compromising quality or distorting the visuals. Perfectly suited for tailoring content to match the unique requirements of platforms like YouTube, Instagram Reels, and countless others.',
#   'faq_rewrite': '```html\n<h2 class="text-2xl font-bold leading-10 tracking-tight text-zinc-100">Common Questions</h2>\n<dl class="mt-10 space-y-6 divide-y divide-white/10">\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rjam7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">What does an AI Image Extender do?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      </button>\n    </dt>\n  </div>\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rlam7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">How does the AI technology expand images?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      </button>\n    </dt>\n  </div>\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rnam7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">Which image file types can I use?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      </button>\n    </dt>\n  </div>\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rpam7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">Are there size limitations for image extensions?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      </button>\n    </dt>\n  </div>\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items-start justify-between text-left text-white" id="headlessui-disclosure-button-:Rram7c6:" type="button" aria-expanded="false" data-headlessui-state="">\n        <span class="text-base font-semibold leading-7">Does the AI support multiple aspect ratios?</span>\n        <span class="ml-6 flex h-7 items-center">\n          <svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" aria-hidden="true" data-slot="icon" class="h-6 w-6">\n            <path stroke-linecap="round" stroke-linejoin="round" d="M12 6v12m6-6H6"></path>\n          </svg>\n        </span>\n      </button>\n    </dt>\n  </div>\n  <div class="pt-6" data-headlessui-state="">\n    <dt>\n      <button class="flex w-full items ...
#   'cta_title_rewrite': 'Beyond Just an AI Image Tool',
#   'cta_content_rewrite': "Transform your creative workflow with BasedLabs—your ultimate AI-powered solution for image and video editing. Our innovative platform goes far beyond simple image extension, allowing you to effortlessly adjust visuals to suit any format, whether for social media posts, marketing campaigns, or professional presentations. But that’s just the beginning.\n\nWith BasedLabs, you unlock access to a complete multimedia editing suite designed to elevate your content creation. Use your extended images to craft engaging videos, enhance your projects, and bring your ideas to life—all in record time. Built for creators of all skill levels, our intuitive tools and preloaded prompts make it easy to produce polished content, whether you're working on personal projects or professional endeavors.\n\nFrom dynamic visuals to captivating videos, BasedLabs empowers you to create with confidence and efficiency. Dive into the limitless possibilities of AI-driven creativity today and discover why BasedLabs is the go-to platform for transforming ideas into stunning results.",
#   'main_image': 'https://cdn.basedlabs.ai/91d4b6e0-1321-11ef-b422-e9e0f1439998.png',
#   'main_image_description': 'The image shows a vibrant composition of a hand illuminated by pink and blue lighting. On the left, a "Magic Expand" tool with a cursor is displayed, demonstrating AI-powered image extension. The right side reveals the extended area seamlessly filled beneath the hand.',
#   'how_to_step1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/f32e174d-a275-43f9-9651-43c6cea86ab3.png?',
#   'how_to_step2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/ef13b3c6-77a1-4b10-b9bd-6e3da7b85cd3.png?',
#   'how_to_step3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/7fba2111-875f-492d-b55c-307829c390f1.png?',
#   'feature1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/0ff48749-08bb-40ab-a376-cf9f5a10e95c.png?',
#   'feature2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/7c0886d3-362e-4c17-aa74-24bad3eb6a47.png?',
#   'feature3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/49ac836f-21b0-45de-afba-ae122fcedf84.png?',
#   'main_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/98433d0a-a6ac-40b8-b911-0f6cbe4bad0c.png?',
#   'title_seo': 'AI Image Extender - Expand and Enhance Your Photos',
#   'description_seo': 'Use AI Image Extender to seamlessly expand and enhance your photos with cutting-edge AI. Transform your visuals in seconds!',
#   'faq_dict': {'What does an AI Image Extender do?': 'An AI Image Extender uses artificial intelligence to expand the boundaries of an image while maintaining consistent style, color, and details, effectively extending the visual content beyond its original frame.',
#    'How does the AI technology expand images?': 'AI technology analyzes the content of the original image, predicts the surrounding context, and generates details to seamlessly extend the image while preserving its visual integrity.',
#    'Which image file types can I use?': 'AI image extenders typically support common file types such as JPEG, PNG, and sometimes TIFF. Specific supported formats may depend on the application or tool used.',
#    'Are there size limitations for image extensions?': 'Yes, there are usually size limitations depending on the software or tool being used. These limitations can vary based on the resolution, initial image size, and available processing power.',
#    'Does the AI support multiple aspect ratios?': "Yes, most AI Image Extenders are designed to support multiple aspect ratios, allowing for flexibility regardless of the image's original dimensions.",
#    'Does the AI Image Extender come at no cost?': 'This depends on the tool or service. Some AI-powered tools are free, while others may require a subscription, one-time payment, or offer limited free usage with premium options for advanced features.'}},
#  {'title': 'AI Profile Picture Generator',
#   'subtitle': 'Stand out online with our AI profile pic maker. Choose a style and background, and get a unique profile picture generated by AI. Create matching images for friends, pets, or teams. Start designing today!',
#   'how_to_use_title': 'How to use AI Profile Picture Generator:',
#   'how_to_step1_image': 'https://cdn.basedlabs.ai/ebdbef90-1322-11ef-aa68-afe163f649bc.png',
#   'how_to_step2_image': 'https://cdn.basedlabs.ai/f4545cc0-1322-11ef-8db3-a768c4e6dce1.png',
#   'how_to_step3_image': 'https://cdn.basedlabs.ai/fcee5bb0-1322-11ef-aa68-afe163f649bc.png',
#   'how_to_step1_title': 'Input Details and Select Model',
# ...
#   'faq_rewrite': '```html\n<h2 class="text-3xl sm:text-4xl font-semibold leading-tight tracking-tight text-zinc-100">Discover More</h2><p class="text-zinc-400">Check out the video tutorial below for an in-depth look at <!-- -->Kling AI</p>\n```',
#   'cta_title_rewrite': 'Beyond Ordinary Kling AI',
#   'cta_content_rewrite': "Unleash your creativity with Basedlabs and Kling AI's cutting-edge image tools. Dive into a powerful suite designed to transform the way you work with visuals—AI-driven image generation, seamless inpainting, advanced upscaling, and realistic face swapping all at your fingertips. Whether you're refining existing photos or crafting entirely new creations, our intuitive tools cater to everyone from hobbyists to seasoned pros. Go beyond video creation and explore a world of endless visual possibilities with Basedlabs.",
#   'main_image': 'https://cdn.basedlabs.ai/0398cb60-9714-11ef-b194-750b5f0f8ab7.jpg',
#   'main_image_description': 'A dimly lit, narrow alley at night with wet cobblestone reflecting vibrant green neon signs reading "kLing" and "AI," surrounded by plants and brick walls.',
#   'how_to_step1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/2ff57257-295a-43d6-8577-4d5638b59477.png?',
#   'how_to_step2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/comfy_383384f4-bba5-4939-ad26-34fd358ea637.png?',
#   'how_to_step3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/2a3f28f4-9719-4269-8aa0-4b794af25921.png?',
#   'feature1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/555dcfae-1de7-4cf7-892d-16e2ee93ccc3.png?',
#   'feature2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/b362c618-0a4e-4098-8423-5e21f1380d9a.png?',
#   'feature3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/comfy_f90fd18d-2d05-450c-bef6-1937327152ae.png?',
#   'main_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/90bfcd7c-063d-45d2-b593-e9657ae897a4.png?',
#   'title_seo': 'Kling AI - Smarter AI Solutions for Your Business',
#   'description_seo': 'Discover Kling AI, the ultimate AI platform offering innovative solutions to streamline workflows and boost your company’s efficiency.',
#   'faq_dict': {"What can I find under 'Discover More'?": 'You can find a video tutorial for an in-depth look at Kling AI.'}},
#  {'title': 'AI Album Cover Generator',
#   'subtitle': "Design your own album covers quickly and easily with BasedLabs' AI-powered generator. Choose from various styles and customize to your liking to create the perfect cover for your music.",
#   'how_to_use_title': 'How to use AI Album Cover Generator:',
#   'how_to_step1_image': 'https://cdn.basedlabs.ai/84f35730-faec-11ee-8f09-01103a7dd87c.png',
#   'how_to_step2_image': 'https://cdn.basedlabs.ai/fefdb610-faec-11ee-9c6c-51624538709b.png',
#   'how_to_step3_image': 'https://cdn.basedlabs.ai/0c06a7e0-faed-11ee-b67e-fd18a7c0fce1.png',
#   'how_to_step1_title': 'Describe Your Album Cover',
#   'how_to_step2_title': 'AI Generation Process',
#   'how_to_step3_title': 'Download Your AI-Generated Album Cover',
#   'how_to_step1_content': 'To get started, input a detailed description of your desired album cover art in the prompt box. Include specific details about the album\'s genre, mood, and visual style, as well as any other relevant keywords or elements you want to be featured in the artwork. Feel free to be as descriptive as possible to guide the AI\'s creative process. Once you\'re satisfied with your prompt, click the "Generate" button to initiate the album cover creation.',
#   'how_to_step2_content': 'Please be patient while the AI analyzes your prompt and generates the album cover artwork. The processing time may vary depending on the complexity of your request and the current system load.',
#   'how_to_step3_content': "Once the AI completes the generation process, your unique album cover artwork will be displayed. If you're satisfied with the result, right click it and save the high-resolution image file. You can then use the AI-generated album cover for your music release, promotional materials, or any other intended purpose.",
#   'feature1_title': "Unleash Your Album's Visual Identity",
#   'feature1_content': "Our AI-powered album cover generator brings your music's essence to life through captivating visuals. By simply describing your album's genre, mood, and desired artistic style, our advanced AI model will create a unique, eye-catching album cover that perfectly represents your sound. Whether you're looking for a photographic, mixed media, or minimalistic design, our tool empowers you to create a professional and memorable album cover in just a few clicks.",
#   'feature1_image': 'https://cdn.basedlabs.ai/6ceceaef-691a-48c4-8836-c9129fa24608.png',
#   'feature2_title': 'Effortless Creation Process',
#   'feature2_content': 'Creating a stunning album cover has never been easier. With our user-friendly interface, you can input your album cover description and let our AI do the heavy lifting. Our advanced algorithms analyze your prompt and generate a visually appealing album cover that aligns with your vision. Say goodbye to the hassle of hiring designers or spending hours on complex design software – our AI album cover generator streamlines the process and delivers results in minutes.',
#   'feature2_image': 'https://cdn.basedlabs.ai/9cf173ba-ffd5-4e10-b282-a402e5ad92e8.png',
#   'feature3_title': 'Unlimited Creative Possibilities',
#   'feature3_content': 'Our AI album cover generator offers a vast array of creative possibilities to suit every musical genre and artistic style. From bold and vibrant designs to subtle and atmospheric compositions, our tool can generate album covers that capture the unique character of your music. Experiment with different prompts and styles to discover the perfect visual representation for your album. With our AI-powered generator, the only limit is your imagination.',
#   'feature3_image': 'https://cdn.basedlabs.ai/d2203f7d-5efb-490d-816a-525d6abeebc0.png',
#   'faq': '<h2 class="text-3xl sm:text-4xl font-semibold leading-tight tracking-tight text-zinc-100">Learn More</h2><p class="text-zinc-400">Watch the tutorial video below to learn more about <!-- -->AI Album Cover Generator</p>',
#   'cta_title': 'More Than Just AI Album Covers',
#   'cta_content': "Our AI-powered platform offers more than just album cover generation. Explore our suite of creative tools for image generation, photo manipulation, and video transformation, all designed to elevate your visual content. Whether you're a professional artist or a content creator, our user-friendly tools empower you to push the boundaries of your creativity and bring your visions to life.",
#   'how_to_step1_image_description': 'A selection menu showing three AI models—AlbedoBase XL, Counterfeit-V3.0, and epicRealism—with descriptions and a "Generate Images" button below.',
#   'how_to_step2_image_description': 'A user interface for an image generation tool is shown. The screen includes options for a negative prompt, number of images, aspect ratio (Square, Landscape, Portrait), and buttons for "Generate Images" and "Open in Editor." A green cursor hovers over the "Landscape" aspect ratio option.',
#   'how_to_step3_image_description': 'A vibrant, abstract digital art composition featuring sharp geometric elements, colorful streaks, and dynamic lighting overlaid on a vivid gradient background.',
#   'feature1_image_description': 'The image features dark, tousled hair surrounded by vibrant splashes and sharp orange-red geometric streaks set against a gradient purple-pink background.',
#   'feature2_image_description': 'Abstract artwork features vibrant splashes of teal, pink, orange, and yellow bursting outward around long, dark hair with purple highlights.',
#   'feature3_image_description': 'A vibrant dripping peace symbol made of orange, purple, pink, and blue paint on a black background.',
#   'title_rewrite': 'Generate Your AI Album Cover',
#   'subtitle_rewrite': "Craft stunning album covers in minutes with BasedLabs' AI-driven generator. Explore diverse styles and tailor every detail to match your music's vibe effortlessly.",
#   'how_to_use_title_rewrite': 'Using the AI Album Cover Generator:',
#   'how_to_step1_title_rewrite': 'Outline Your Cover Vision',
#   'how_to_step1_content_rewrite': '**Step 1: Describe Your Vision**  \nKickstart your album cover journey by sharing your creative vision in the prompt box. Paint a vivid picture of what you want your artwork to embody—include the genre of your music, the mood you\'re aiming for, and the visual style that reflects your sound. Don’t hold back! Add any specific elements, themes, or keywords that will help bring your concept to life. The more detail you provide, the better the AI can tailor the design to match your imagination. When your prompt feels just right, hit the "Generate" button and watch your artistic idea transform into reality.',
#   'how_to_step2_title_rewrite': 'Generating with AI',
#   'how_to_step2_content_rewrite': '**Step 2: Watch the Magic Unfold**\n\nSit tight as our AI dives into your prompt, meticulously crafting your unique album cover. The creation process may take a little time, depending on how detailed your request is and the system’s activity level. Rest assured, every second is spent ensuring your artwork is stunning and tailored to your vision!',
#   'how_to_step3_title_rewrite': 'Get Your Custom AI Album Cover Instantly',
#   'how_to_step3_content_rewrite': '**Step 3: Download Your Stunning Album Cover**  \n\nAfter the AI has worked its magic, your one-of-a-kind album cover will be ready for you to view. The finished design, crafted specifically for your vision, will appear on the screen in all its high-resolution glory. If the artwork feels perfect and captures the essence of your music, simply right-click on the image and save it to your device.  \n\nFrom there, the possibilities are endless. Whether you’re preparing for a music launch, designing promotional assets, or showcasing your creativity to the world, your AI-generated album cover is ready to become a part of your journey.',
#   'feature1_title_rewrite': "Bring Your Album's Vision to Life",
#   'feature1_content_rewrite': 'Transform your music into a visual masterpiece with the power of AI. Our cutting-edge album cover generator turns your sound into stunning artwork that captures its true essence. Just share a few details—describe your genre, the mood you want to evoke, and the artistic style you envision—and watch as our advanced AI crafts a one-of-a-kind design tailored to your music. From striking photography to bold mixed media or sleek minimalism, the possibilities are endless. With just a few clicks, you’ll have a professionally designed album cover that not only stands out but tells your story at first glance.',
#   'feature2_title_rewrite': 'Seamless Building Made Easy',
#   'feature2_content_rewrite': 'Designing a breathtaking album cover is now simpler than ever. Our intuitive platform empowers you to craft the perfect cover with minimal effort. Just provide a description of your vision, and our cutting-edge AI takes care of the rest. By analyzing your input, it creates a captivating design that perfectly captures the essence of your music. Forget the stress of hiring professionals or navigating complicated design tools—our AI-driven album cover generator makes the process effortless, delivering stunning results in just a matter of minutes.',
#   'feature3_title_rewrite': 'Boundless Ways to Create',
#   'feature3_content_rewrite': '**Bring Your Music to Life with Stunning AI-Generated Album Covers**  \nUnleash your creativity with our cutting-edge AI album cover generator, designed to craft visuals as diverse as the music they represent. Whether your sound is electric and energetic or moody and introspective, our tool offers endless design possibilities that align perfectly with your artistic vision. Dive into a world of bold colors, intricate patterns, and subtle textures, all tailored to convey the essence of your unique sound. Simply input your ideas, explore a variety of styles, and watch as your album’s personality comes to life in breathtaking detail. With limitless options at your fingertips, your next masterpiece is just a click away.',
#   'faq_rewrite': '```html\n<h2 class="text-3xl sm:text-4xl font-semibold leading-tight tracking-tight text-zinc-100">Discover More</h2>\n<p class="text-zinc-400">Check out the tutorial video below to explore all the features of the <!-- -->AI Album Cover Generator</p>\n```',
#   'cta_title_rewrite': 'Beyond AI: Album Art Redefined',
#   'cta_content_rewrite': 'Unleash your creative potential with our cutting-edge AI platform. Beyond crafting stunning album covers, we provide a full spectrum of innovative tools designed to redefine visual content creation. From breathtaking image generation to seamless photo manipulation and dynamic video transformations, our platform equips you with everything you need to create like never before. Ideal for professional artists and content creators alike, our intuitive tools make it easier than ever to turn your boldest ideas into reality. Dive in and discover how we can help you transform imagination into art.',
#   'main_image': 'https://cdn.basedlabs.ai/4cb33470-faed-11ee-b67e-fd18a7c0fce1.png',
#   'main_image_description': 'A surreal landscape featuring a large, textured yellow sun against a vivid pink sky, silhouetted trees, and distant mountains.',
#   'how_to_step1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/8cda96e0-e4b6-48aa-aece-69b16e921ccb.png?',
#   'how_to_step2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/3aaef2b5-c084-400e-b90c-ddd3c50f6eb7.png?',
#   'how_to_step3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/c67700f8-5bc9-4457-928e-2f73f7b551be.png?',
#   'feature1_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/29567cfa-a331-4145-aec9-5276c888dfe6.png?',
#   'feature2_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/a8c91555-9709-45b2-be9a-489dfb12cb61.png?',
#   'feature3_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/7d63bbb7-339f-4977-9a0e-4711152c51c3.png?',
#   'main_image_gend': 'https://bjqbwtqznzladztznntj.supabase.co/storage/v1/object/public/images/ai-generator-images/93780f1f-ee11-4356-9499-699c20f31665.png?',
#   'title_seo': 'AI Album Cover Generator: Customize Your Art',
#   'description_seo': 'Design stunning album covers effortlessly with AI. Create unique, customizable designs for music and art projects in seconds.',
#   'faq_dict': {'What is the purpose of the tutorial video mentioned?': 'The tutorial video is designed to help viewers explore all the features of the AI Album Cover Generator.'}}]

# %%
with open("ai_girls_landing_pages.json", "r") as f:
    ai_girls_results = json.load(f)

ai_girls_results
# Out:
# {'nude girl': {'title': 'AI Nude Girl Generator',
#   'subtitle': 'Create custom AI-generated figures with advanced image generation technology. Craft detailed, realistic images in seconds through intuitive text prompts.',
#   'how_to_use_title': 'How to Use the AI Nude Girl Generator:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': 'Enter a detailed text prompt specifying your desired figure’s pose, style, and artistic direction. Use descriptive keywords to guide the AI’s creative process for optimal results.',
#   'how_to_step2_title': 'AI Processing',
#   'how_to_step2_content': 'Our advanced neural network analyzes your input to generate a high-resolution image. Processing typically takes 10-20 seconds, depending on complexity and server load.',
#   'how_to_step3_title': 'Export & Utilize',
#   'how_to_step3_content': 'Download your AI-generated image in PNG or JPEG format. Use it for artistic projects, 3D modeling references, or creative concept development with full commercial rights.',
#   'feature1_title': 'Precision Customization',
#   'feature1_content': 'Fine-tune every detail via text prompts, from body proportions to lighting conditions. Our AI interprets nuanced descriptions to deliver images that match your exact specifications.',
#   'feature2_title': 'Intuitive Interface',
#   'feature2_content': 'No technical expertise required. Our streamlined platform guides you through the creation process with smart suggestions and real-time preview options.',
#   'feature3_title': 'Photorealistic Output',
#   'feature3_content': 'Generate studio-quality images with accurate anatomy and texture details. Advanced rendering algorithms ensure professional-grade results for artistic or technical applications.',
#   'cta_title': 'Unlock Creative Potential with AI',
#   'cta_content': 'Beyond figure generation, explore our suite of professional AI tools for photo enhancement, style transfer, and 3D model creation. Perfect for artists, designers, and content creators seeking cutting-edge visual solutions. Start your free trial today.',
#   'faq_dict': {'Is this tool suitable for professional artists?': 'Absolutely. Many digital artists use our generator for concept development and anatomical reference creation with commercial-grade output quality.',
#    'How does the AI ensure anatomical accuracy?': 'Our models are trained on curated artistic datasets with built-in proportional validation systems for realistic human figure generation.',
#    'Can I edit generated images post-creation?': 'Yes. Downloaded images come with full editing rights for use in Photoshop, Blender, or other creative software.',
#    'What hardware requirements are needed?': 'Our cloud-based platform works on any modern browser. No specialized hardware required – process occurs on our secure servers.',
#    'Are generations private and secure?': 'All creations are encrypted and stored anonymously. We adhere to strict data protection standards (GDPR compliant).'},
#   'title_seo': 'AI Nude Image Generator: Custom Photorealistic Figures',
#   'description_seo': 'Professional AI tool for generating customizable human figures. Create detailed, realistic images securely. Ideal for artists and designers.'},
#  'sexy girl': {'title': 'AI Femme Generator: Precision-Crafted Digital Portraits',
#   'subtitle': 'Transform your creative vision into stunning AI-generated portraits with cutting-edge technology. Design elegant, customizable characters in seconds—no technical expertise required.',
#   'how_to_use_title': 'How to Create Your AI-Generated Portrait:',
#   'how_to_step1_title': 'Define Your Concept',
#   'how_to_step1_content': 'Input your vision into the description field using keywords for style, aesthetics, and personality traits. Our AI interprets details like pose, wardrobe, and ambiance to align with your preferences.',
#   'how_to_step2_title': 'AI Processing',
#   'how_to_step2_content': 'Our neural networks analyze your input to generate a base image within 15 seconds. Advanced algorithms ensure anatomical accuracy and artistic coherence while maintaining your specified style.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Use our integrated editing tools to adjust lighting, composition, or details. Export your final portrait in 4K resolution (JPEG/PNG) or access layered files for professional projects.',
#   'feature1_title': 'Hyper-Personalized Creation',
#   'feature1_content': 'Leverage granular control over 50+ parameters including facial structure, fashion style, and environmental settings. Our AI adapts to your unique preferences while maintaining natural proportions.',
#   'feature2_title': 'Style Fusion Technology',
#   'feature2_content': 'Combine multiple artistic influences seamlessly—mix photorealistic rendering with anime aesthetics or vintage art styles using our proprietary style-blending algorithms.',
#   'feature3_title': 'Ethical AI Framework',
#   'feature3_content': 'Built with content safety protocols and watermarking technology to ensure responsible creation. All outputs are processed through privacy-first servers with encrypted data handling.',
#   'cta_title': 'Elevate Your Creative Projects',
#   'cta_content': 'Beyond portrait generation, unlock advanced tools for animation prototyping, persona development, and digital storytelling. Join 150,000+ creators using our platform for character design, marketing visuals, and immersive world-building.',
#   'faq_dict': {'What technical specifications do the images have?': 'Outputs are generated at 4096x4096 resolution with support for 16-bit color depth. Files are optimized for both digital use and professional printing.',
#    'Can I request specific artistic styles?': 'Yes—our system recognizes 120+ documented art movements and contemporary styles. Combine multiple references using our style syntax for hybrid creations.',
#    'How does the AI ensure diverse representation?': 'Our models are trained on ethically sourced datasets with balanced representation across 12 demographic categories, ensuring inclusive output generation.',
#    'Are there usage restrictions for commercial projects?': 'Generated images include full commercial rights with attribution. Review our licensing agreement for enterprise-level usage terms.',
#    'What security measures protect user data?': 'All inputs and outputs are processed through AES-256 encrypted pipelines. User activity logs are automatically purged every 72 hours.'},
#   'title_seo': 'AI Femme Generator | Custom Portrait Creation Tool',
#   'description_seo': 'Generate sophisticated AI portraits with advanced customization. Professional-grade results in seconds. Ethical AI, commercial rights included.'},
#  'hot girl': {'title': 'AI Hot Girl Generator: Craft Your Perfect Digital Muse',
#   'subtitle': 'Transform your creative vision into stunning AI-generated art with precision and ease. Leverage advanced AI technology to design lifelike, customizable characters in seconds—no technical expertise required.',
#   'how_to_use_title': 'How to Use the AI Hot Girl Generator:',
#   'how_to_step1_title': 'Define Your Vision',
#   'how_to_step1_content': "Enter a detailed description of your ideal character in the prompt field. Include attributes like style, pose, and aesthetic preferences to guide the AI. Click 'Generate' to start the process.",
#   'how_to_step2_title': 'AI Processing',
#   'how_to_step2_content': 'Our advanced algorithm interprets your input and creates a unique rendering. Wait just moments for the system to craft high-quality, photorealistic results tailored to your specifications.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Preview your AI-generated image, make adjustments using intuitive editing tools, then download in your preferred format. Your creation is ready for personal or commercial projects.',
#   'feature1_title': 'Customizable AI Personalization',
#   'feature1_content': 'Fine-tune every detail—from facial features to wardrobe—using natural language prompts. Our AI adapts to your creative direction, delivering results that align with your unique vision.',
#   'feature2_title': 'Intuitive Creation Process',
#   'feature2_content': "Designed for creators of all skill levels. The platform's clean interface and smart suggestions eliminate guesswork, making professional-grade character design accessible to everyone.",
#   'feature3_title': 'High-Resolution Output',
#   'feature3_content': 'Generate print-ready 4K images with realistic textures, lighting, and proportions. Our AI ensures studio-quality results suitable for digital art, concept design, or multimedia projects.',
#   'cta_title': 'Unlock Creative Possibilities',
#   'cta_content': 'Beyond character generation, explore our suite of AI-powered creative tools. Enhance images, animate designs, or integrate creations into videos—all within a secure, user-friendly ecosystem designed for innovators.',
#   'faq_dict': {'How does the AI ensure diverse character creation?': 'Our algorithm incorporates extensive datasets to generate varied ethnicities, body types, and styles, ensuring inclusive and adaptable outputs.',
#    'What are the commercial use terms?': 'Users retain full rights to generated images. Review our licensing agreement for specific commercial application guidelines.',
#    'Can I edit images after generation?': 'Yes—use built-in tools to adjust colors, proportions, and backgrounds, or regenerate specific elements while preserving original composition.',
#    'How long does image generation take?': 'Most renders complete in 10-30 seconds. Complex requests may take up to 1 minute depending on server load.',
#    'Is user input data stored?': 'All prompts and generated images are encrypted and anonymized. We never share or reuse personal creative data.'},
#   'title_seo': 'AI Hot Girl Generator: Custom Digital Muse Creator',
#   'description_seo': 'Design lifelike AI characters with precision. Professional-grade image generation tool for creatives. Fast, secure, and customizable.'},
#  'little girl': {'title': 'AI Little Girl Generator',
#   'subtitle': 'Craft lifelike AI-generated characters with precision. Perfect for creative projects, storytelling, and family-friendly content – no technical expertise required.',
#   'how_to_use_title': 'How to Use the AI Little Girl Generator:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': "Enter a detailed prompt describing the character’s appearance, including age, facial expression, clothing, and setting. Use keywords like 'playful', 'bookish', or 'adventurous' to guide the AI. Click 'Generate' to begin.",
#   'how_to_step2_title': 'AI Processing',
#   'how_to_step2_content': 'Our advanced algorithms analyze your input and generate high-resolution images in under 30 seconds. All outputs comply with strict ethical guidelines to ensure age-appropriate, safe content.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Review the generated image, adjust details using sliders or text prompts, then download in PNG or JPEG format. Images are royalty-free for personal or commercial use.',
#   'feature1_title': 'Custom Character Design',
#   'feature1_content': 'Tailor every aspect of your AI-generated character, from hairstyle to accessories, using natural language prompts. Ideal for illustrators, authors, and content creators needing unique visuals.',
#   'feature2_title': 'Intuitive AI Technology',
#   'feature2_content': 'Powered by state-of-the-art generative AI, our platform requires no artistic skills. Generate diverse, culturally representative characters with a single text input.',
#   'feature3_title': 'Ethical AI Practices',
#   'feature3_content': 'Built with child safety prioritization, featuring automated content filters and strict moderation to ensure all outputs remain wholesome and project-appropriate.',
#   'cta_title': 'Unlock Creative Potential with AI',
#   'cta_content': 'Beyond character generation, explore our suite of family-friendly AI tools for animations, illustrated storyboards, and educational content. Join 50,000+ creators transforming their visions into reality – no design experience needed.',
#   'faq_dict': {'What applications does this tool support?': 'Ideal for children’s book illustrations, game design, educational materials, and family-oriented content creation.',
#    'How do you ensure generated content is appropriate?': 'Our AI uses layered safety protocols, including automatic content filtering and manual review systems, to maintain strict ethical standards.',
#    'Can I customize the character’s cultural background?': 'Yes. Specify traits like ethnicity, traditional clothing, or regional features in your prompt for culturally sensitive results.',
#    'Are generated images copyrighted?': 'Users retain full commercial rights to all images created, with no attribution required. See our licensing terms for details.',
#    'What technical specifications do images have?': 'Images export as 2048x2048px resolution PNG/JPEG files (300 DPI), optimized for print and digital use.'},
#   'title_seo': 'AI Little Girl Generator: Create Custom Child Characters Safely',
#   'description_seo': 'Generate lifelike AI child characters for creative projects. Safe, ethical, and user-friendly. Start creating now!'},
#  'teen girl': {'title': 'AI Teen Girl Generator',
#   'subtitle': 'Craft authentic AI-generated teen girl characters with precision. Generate lifelike images in any style or pose using advanced AI technology—no design experience required.',
#   'how_to_use_title': 'How to Use the AI Teen Girl Generator:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': "Enter a detailed description of your desired character in the prompt field. Specify features like hairstyle, clothing, expression, and background elements to guide the AI. Use keywords such as 'anime-style,' 'realistic,' or 'cartoon' to define the art direction.",
#   'how_to_step2_title': 'Generate Your Image',
#   'how_to_step2_content': "Click 'Create' to let our AI process your request. The system leverages stable diffusion algorithms to interpret your description and render a high-quality image within 15-30 seconds.",
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Review your generated image and use our editing tools to adjust details like lighting or proportions. Download your final artwork in PNG or JPEG format for personal or commercial projects.',
#   'feature1_title': 'Dynamic Style Customization',
#   'feature1_content': 'Create characters tailored to your needs—choose between anime, realistic, or illustrated styles. Adjust age ranges, outfits, and settings with simple text prompts for endless creative possibilities.',
#   'feature2_title': 'Intuitive AI Technology',
#   'feature2_content': 'Our proprietary neural networks analyze prompts contextually to maintain anatomical accuracy and artistic coherence. Advanced pose estimation ensures natural-looking results every time.',
#   'feature3_title': 'High-Resolution Output',
#   'feature3_content': 'Download images up to 4K resolution with sharp details and vibrant colors. Perfect for game design, concept art, or social media content creation.',
#   'cta_title': 'Unlock Next-Level Character Design',
#   'cta_content': 'Beyond image generation, explore our suite of AI creative tools. Enhance outputs with background removal filters, batch processing, and multi-angle view generation. Join 500,000+ creators transforming their vision into reality—start your free trial today.',
#   'faq_dict': {'Is this tool suitable for professional artists?': 'Yes—our AI assists with concept ideation and rapid prototyping while maintaining full creative control. Outputs can be refined in standard design software.',
#    'What ethical guidelines govern image generation?': 'We enforce strict content policies prohibiting harmful or explicit material. All outputs are filtered through advanced safety classifiers.',
#    'Can I use generated images commercially?': 'You retain full commercial rights to all creations. Review our licensing agreement for detailed terms.',
#    'How does the AI handle specific details?': 'The model references artistic patterns while avoiding direct replication. For precise adjustments, use our manual refinement tools post-generation.',
#    'What payment plans are available?': 'Choose from pay-as-you-go credits or monthly subscriptions. Educational and enterprise discounts are available for qualifying users.'},
#   'title_seo': 'AI Teen Girl Generator: Custom Anime & Realistic Characters',
#   'description_seo': 'Create AI-generated teen girl characters in any style. Customize outfits, poses, and art styles instantly with advanced AI technology.'},
#  'nn girl': {'title': 'AI Nn Girl Generator',
#   'subtitle': 'Craft lifelike, custom AI-generated characters in seconds. Transform your creative vision into stunning digital art with advanced AI image generation—no technical skills required.',
#   'how_to_use_title': 'How to Create Your AI Nn Girl:',
#   'how_to_step1_title': 'Define Your Vision',
#   'how_to_step1_content': "Enter a detailed description of your desired character in the input field. Include specifics like hairstyle, outfit, pose, or background elements to guide the AI. Use clear keywords for optimal results, then click 'Generate.'",
#   'how_to_step2_title': 'AI Generation Process',
#   'how_to_step2_content': 'Our advanced AI analyzes your prompt and generates high-quality artwork in under 30 seconds. Complex requests may take slightly longer, but you’ll receive real-time updates on the progress.',
#   'how_to_step3_title': 'Refine & Download',
#   'how_to_step3_content': 'Preview your AI-generated character, refine details using intuitive editing tools, and download in your preferred format (PNG, JPEG, or SVG). Use your creation commercially or personally with full rights.',
#   'feature1_title': 'Unmatched Customization',
#   'feature1_content': 'Generate characters tailored to your exact specifications. Adjust facial features, expressions, clothing, and environments through text prompts or sliders for pixel-perfect results.',
#   'feature2_title': 'Studio-Grade AI Technology',
#   'feature2_content': 'Powered by cutting-edge diffusion models, our generator produces 4K-resolution art with realistic lighting, textures, and proportions. Ideal for digital artists, game developers, and content creators.',
#   'feature3_title': 'Batch Generation Mode',
#   'feature3_content': 'Produce multiple character variations simultaneously. Compare styles, poses, and themes efficiently—perfect for prototyping concepts or building diverse character libraries.',
#   'cta_title': 'Elevate Your Creative Workflow',
#   'cta_content': 'Join 500,000+ designers and storytellers using our AI Nn Girl Generator. Start with 10 free credits—no payment required. Upgrade to unlock premium features like 8K exports, priority rendering, and custom model training.',
#   'faq_dict': {'What makes this different from other AI generators?': 'Our specialized model focuses on human character synthesis with anatomical accuracy and style flexibility, supporting both anime and photorealistic outputs.',
#    'Can I use these images commercially?': 'Yes—all generated artwork is royalty-free. Use it in games, merchandise, or marketing materials without attribution.',
#    'How do I ensure privacy for my generated content?': 'All prompts and outputs are encrypted and never shared. Delete generations permanently from our servers anytime via your dashboard.',
#    'What hardware/software do I need?': 'No installations required. Our cloud-based tool works on all modern browsers. Optimized for mobile, tablet, and desktop use.',
#    'Do you offer enterprise solutions?': 'Yes—contact us for custom API integration, volume licensing, or dedicated GPU clusters for large-scale projects.'},
#   'title_seo': 'AI Nn Girl Generator: Custom Character Creation Tool',
#   'description_seo': 'Design unique AI-generated characters instantly with advanced customization. Perfect for digital artists & developers. Start creating now!'},
#  'bikini girl': {'title': 'AI Bikini Girl Generator',
#   'subtitle': 'Craft lifelike AI-generated beach imagery in seconds. Leverage advanced AI technology to create customized swimwear concepts with precision—no design experience required.',
#   'how_to_use_title': 'How to Use the AI Bikini Girl Generator:',
#   'how_to_step1_title': 'Input Your Vision',
#   'how_to_step1_content': 'Describe your ideal beach scene or swimwear design in the prompt box. Use specific details like pose, background, style, and accessories to guide the AI. Click "Generate" to begin.',
#   'how_to_step2_title': 'AI Generation Process',
#   'how_to_step2_content': 'Our neural network processes your description using advanced diffusion models, rendering a high-quality image in under 30 seconds. Complex requests may take slightly longer.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Review your AI-generated image and use built-in tools to adjust lighting, colors, or composition. Download in JPEG/PNG formats at up to 4K resolution for commercial or personal projects.',
#   'feature1_title': 'Precision Style Customization',
#   'feature1_content': 'Fine-tune every detail—from swimsuit patterns to beach environments—using natural language prompts. Our AI interprets complex requests to match your creative vision.',
#   'feature2_title': 'Photorealistic Output',
#   'feature2_content': 'Generate studio-quality imagery with accurate anatomy, textures, and lighting. Advanced GAN architecture ensures professional-grade results for marketing, design, or entertainment use.',
#   'feature3_title': 'Ethical AI Framework',
#   'feature3_content': 'Built with responsible AI practices, our generator uses curated datasets to produce tasteful, copyright-compliant imagery. All outputs undergo automated content quality checks.',
#   'cta_title': 'Elevate Your Creative Projects with AI',
#   'cta_content': 'Our platform offers more than swimwear generation—explore tools for fashion design, background replacement, and dynamic pose adjustment. Integrate AI-generated assets into campaigns, portfolios, or digital content with full commercial rights. Start your free trial today.',
#   'faq_dict': {'What technical specifications do the images have?': 'Images are generated at 4096x4096 resolution with support for post-processing effects. Outputs maintain professional-grade color accuracy and detail.',
#    'Can I use these images for commercial purposes?': 'All generated content includes full commercial usage rights. We recommend reviewing local regulations regarding AI-generated media.',
#    'How does the AI ensure diverse representation?': 'Our models are trained on globally diverse datasets, with optional parameters for ethnicity, body type, and age in generation prompts.',
#    'What languages does the generator support?': 'Currently optimized for English prompts, but supports basic multilingual input. Precision improves with English technical descriptors.',
#    'Is there a content moderation system?': 'Yes—all generations pass through automated ethical guidelines checks to ensure appropriate, non-explicit outputs aligned with our content policy.'},
#   'title_seo': 'AI Bikini Girl Generator: Create Custom Beach Imagery',
#   'description_seo': 'Generate AI-crafted beach imagery with precise customization. Instant high-quality results for creative projects. Try now!'},
#  'anime girl': {'title': 'AI Anime Girl Generator',
#   'subtitle': 'Craft your perfect anime companion with cutting-edge AI technology. Generate custom anime girl art in any style or pose—no design skills required.',
#   'how_to_use_title': 'How to Create AI Anime Art:',
#   'how_to_step1_title': 'Describe Your Character',
#   'how_to_step1_content': "Enter detailed attributes like hairstyle, outfit, and personality traits in the text prompt. Use keywords to specify art styles (e.g., 'chibi,' 'realistic,' or 'retro anime') for optimal AI interpretation.",
#   'how_to_step2_title': 'Initiate AI Processing',
#   'how_to_step2_content': "Click 'Generate' to let our neural networks analyze your request. The system processes complex details like lighting, proportions, and thematic elements in under 30 seconds.",
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Adjust facial expressions, color schemes, or accessories using intuitive editing tools. Download your finished artwork in 4K resolution (JPEG/PNG) for personal or commercial projects.',
#   'feature1_title': 'Precision Customization',
#   'feature1_content': 'Our AI analyzes 50+ visual parameters to match your exact specifications, from eye sparkle effects to dynamic pose generation. Advanced style transfer ensures consistency with classic or modern anime aesthetics.',
#   'feature2_title': 'Real-Time AI Rendering',
#   'feature2_content': 'Powered by Stable Diffusion architecture optimized for anime workflows, generating high-fidelity artwork 3x faster than standard image generators while maintaining intricate details.',
#   'feature3_title': 'Professional-Grade Output',
#   'feature3_content': 'Export production-ready 4096x4096px images with layered depth. Ideal for game developers, illustrators, and content creators needing commercial-quality character designs.',
#   'cta_title': 'Transform Ideas into Anime Reality',
#   'cta_content': 'Elevate your creative projects with AI-generated anime art that adapts to your vision. Integrate characters into animations, merchandise designs, or social media content. Join 250,000+ creators transforming imagination into art—start your free trial today.',
#   'faq_dict': {'How specific should my description be?': 'The AI works best with 3-5 descriptive sentences. Include key elements like hair color, outfit details, mood, and background preferences for optimal results.',
#    'Can I replicate specific anime art styles?': "Yes. Use style keywords like 'Studio Ghibli aesthetic' or '90s shoujo' in your prompt. Our AI has been trained on 2M+ anime images for accurate style emulation.",
#    'Are generated images royalty-free?': 'All outputs include commercial usage rights. You retain full ownership of created artworks for merchandise, games, or publications.',
#    'How does the AI ensure anatomical accuracy?': 'Our proprietary model uses pose estimation algorithms and anime-specific proportion databases to maintain consistent character anatomy across all generations.',
#    'What security measures protect my data?': 'All prompts and generated images are encrypted via AES-256 standards. We never share or store user data beyond essential processing requirements.'},
#   'title_seo': 'AI Anime Girl Generator - Create Custom Anime Characters',
#   'description_seo': 'Generate unique AI anime girls with advanced technology. Customize styles, poses & details instantly. Start creating now!'},
#  'tween girl': {'title': 'AI Tween Girl Generator',
#   'subtitle': 'Craft lifelike AI-generated tween characters instantly with advanced image generation technology. Perfect for storytelling, avatars, or creative projects—no design skills required.',
#   'how_to_use_title': 'How to Use the AI Tween Girl Generator:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': "Enter details about your desired character in the prompt box. Include specifics like hairstyle, clothing, expression, and background to guide the AI. Use keywords like 'playful', 'athletic', or 'fantasy-themed' for best results.",
#   'how_to_step2_title': 'Generate with AI',
#   'how_to_step2_content': "Click 'Generate' to let our AI process your input. The system uses advanced diffusion models to create a unique, high-resolution character in under 15 seconds.",
#   'how_to_step3_title': 'Customize & Download',
#   'how_to_step3_content': 'Refine details using our editing tools, then download your image in PNG or JPEG format. Images are ready for social media, illustrations, or 3D model integration.',
#   'feature1_title': 'Dynamic Customization',
#   'feature1_content': 'Adjust age-appropriate features like height, facial expressions, and outfits with precision. Our AI maintains realistic proportions while respecting ethical guidelines for youth-focused content.',
#   'feature2_title': 'Style Adaptability',
#   'feature2_content': 'Generate characters in multiple art styles—from cartoonish to photorealistic. Perfect for consistent character design across animation, gaming, or educational projects.',
#   'feature3_title': 'Ethical AI Guardrails',
#   'feature3_content': 'Built-in safeguards ensure all generated content remains age-appropriate and compliant with COPPA regulations. Automatic filters maintain wholesome, creative outputs.',
#   'cta_title': 'Unlock Creative Potential with AI',
#   'cta_content': 'Our platform offers more than character generation—explore tools for animation prep, outfit design, and scene creation. Join 50,000+ educators, authors, and digital artists transforming youth-focused content creation with ethical AI.',
#   'faq_dict': {"What age range does 'tween' cover?": 'Our AI generates characters aged 9-12 with appropriate features. Outputs automatically exclude mature characteristics to align with youth content standards.',
#    'Can I use these images commercially?': 'Yes. All generated images include full commercial rights for branding, merchandise, and media projects. Attribution is not required.',
#    'How does the AI ensure age-appropriateness?': 'Multiple safety layers filter prompts and outputs, including automatic moderation for clothing, poses, and contexts. Our models are trained on ethically sourced datasets.',
#    'What resolution are the generated images?': 'Images output at 4K resolution (4096x4096px) with optional upscaling. Files retain detail for both digital use and print applications.',
#    'Is there a content review process?': 'All generations undergo automated checks before download. Users can flag concerns for human moderation to maintain community standards.'},
#   'title_seo': 'AI Tween Girl Generator: Custom Character Creation Tool',
#   'description_seo': 'Design unique AI-generated tween characters instantly. Safe, customizable tool for authors, educators, and creators. Start generating today!'},
#  'girls porn': {'title': 'AI Character Generator',
#   'subtitle': 'Craft unique AI-generated characters with precision using advanced image generation technology. Describe your vision and let our AI produce photorealistic results in seconds—no technical expertise required.',
#   'how_to_use_title': 'How to Use the AI Character Generator:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': 'Enter a detailed description of your desired character in the prompt field. Include specifics like style, attire, and mood to guide the AI. Click "Generate" to begin the creation process.',
#   'how_to_step2_title': 'AI Processing',
#   'how_to_step2_content': 'Our advanced AI algorithms analyze your input and generate high-quality imagery. This typically takes under 15 seconds, depending on complexity and server load.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Review your generated image, adjust details if needed, and download it in your preferred format. Use your creation for personal projects, concept art, or digital content.',
#   'feature1_title': 'Unmatched Customization',
#   'feature1_content': 'Tailor every aspect of your character’s appearance using natural language prompts. Our AI interprets nuanced descriptions to deliver results that align with your creative vision.',
#   'feature2_title': 'Intuitive Design Interface',
#   'feature2_content': 'A streamlined platform built for creators of all skill levels. Focus on your ideas while our AI handles the technical execution, from lighting to texture details.',
#   'feature3_title': 'Professional-Grade Output',
#   'feature3_content': 'Generate studio-quality 4K images with realistic lighting, shadows, and textures. Ideal for digital artists, content creators, and concept designers seeking polished results.',
#   'cta_title': 'Expand Your Creative Toolkit',
#   'cta_content': 'Our platform offers more than character generation—explore AI-powered photo enhancement, video editing, and style transfer tools. Join a community of innovators pushing the boundaries of AI-assisted creativity. Start your free trial today!',
#   'faq_dict': {'What input details work best for character generation?': 'Focus on specific attributes like hairstyle, clothing, pose, and background. The more descriptive your prompt, the more accurate the results.',
#    'Is there a limit on image generations?': 'Free tier users receive 10 generations per month. Premium plans offer unlimited creations and advanced editing features.',
#    'How does the AI ensure image originality?': 'Our models are trained on diverse datasets and apply unique style randomization to produce one-of-a-kind results for every prompt.',
#    'What commercial rights do I have for generated images?': 'Users retain full commercial rights to all creations. Review our licensing agreement for complete details.',
#    'Can I edit existing generated images?': 'Yes! Use our integrated editing suite to refine colors, adjust compositions, or combine multiple AI-generated elements.'},
#   'title_seo': 'AI Character Generator: Craft Unique Digital Creations',
#   'description_seo': 'Design custom AI-generated characters with advanced technology. Easy to use, high-quality results. Start creating now!'},
#  'young girl': {'title': 'AI Young Girl Generator',
#   'subtitle': 'Transform your creative concepts into lifelike AI-generated characters with precision. Design custom young female personas in seconds using cutting-edge AI technology.',
#   'how_to_use_title': 'How to Create AI-Generated Characters:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': "Enter detailed characteristics like hairstyle, clothing, expression, and setting in the description box. Use specific keywords (e.g., 'athletic build with braided hair in a forest scene') to guide the AI's creative process.",
#   'how_to_step2_title': 'Initiate AI Generation',
#   'how_to_step2_content': "Click 'Generate' to activate our neural network. The system analyzes your input using advanced Stable Diffusion algorithms to craft photorealistic results within 15-30 seconds.",
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Use built-in editing tools to adjust lighting, proportions, or backgrounds. Download your high-resolution image (up to 4K) in PNG or JPEG format for personal or commercial projects.',
#   'feature1_title': 'Photorealistic AI Rendering',
#   'feature1_content': 'Our GAN-based architecture produces images with authentic facial features, natural textures, and dimensional lighting. Achieve studio-quality character designs without photography equipment.',
#   'feature2_title': 'Dynamic Style Adaptation',
#   'feature2_content': "Generate characters in any aesthetic—from anime-inspired illustrations to hyper-realistic portraits. Specify art styles like 'watercolor' or 'cinematic lighting' for tailored results.",
#   'feature3_title': 'Ethical AI Framework',
#   'feature3_content': 'Built with responsible innovation principles, our generator uses curated datasets and content filters to ensure all outputs comply with digital safety standards and copyright regulations.',
#   'cta_title': 'Unlock Next-Gen Character Design',
#   'cta_content': 'Beyond standalone images, integrate your AI-generated characters into animations, game assets, or marketing materials using our pro editing suite. Access batch processing, pose adjustment tools, and style transfer filters with premium plans.',
#   'faq_dict': {'Is this tool suitable for professional artists?': 'Yes, our generator serves both casual users and professionals needing base character models for concept art, illustrations, or 3D modeling projects.',
#    'What resolution are the generated images?': 'Outputs range from 1024x1024px to 4096x4096px depending on your subscription tier, with optional upscaling features.',
#    'Can I specify unique accessories or props?': "Absolutely. Include descriptors like 'holding a vintage camera' or 'wearing steampunk goggles' to add personalized elements to your design.",
#    'How does the free trial work?': 'New users receive 5 standard-resolution generations per month. Premium plans unlock HD outputs, priority processing, and advanced editing tools.',
#    'Are generated images royalty-free?': 'You retain full commercial rights to all original creations. Review our content policy for guidelines on derivative works and redistribution.'},
#   'title_seo': 'AI Young Girl Generator: Custom Character Design Tool',
#   'description_seo': 'Create unique AI-generated characters with advanced customization. Professional-grade rendering for artists & creators. Start designing now!'},
#  'girl in panties': {'title': 'AI Girl In Panties Generator',
#   'subtitle': 'Craft detailed AI-generated images with precision using advanced neural networks. Create custom fashion-inspired visuals in seconds—no technical expertise required.',
#   'how_to_use_title': 'How to Use the AI Image Generator:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': "Enter a detailed text prompt describing your desired image, including preferences for poses, lighting, attire details, and artistic style. Use clear language to guide the AI's creative process.",
#   'how_to_step2_title': 'AI Processing',
#   'how_to_step2_content': 'Our advanced algorithms analyze your input to generate a draft image. The system optimizes anatomical proportions, fabric textures, and lighting for photorealistic results.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Adjust details using sliders for pose refinement or style tweaks. Download your high-resolution image in PNG or JPEG format for personal or commercial projects.',
#   'feature1_title': 'AI-Driven Customization',
#   'feature1_content': 'Fine-tune every aspect of your generated image with granular controls for body positioning, outfit details, and environmental elements. The AI adapts to complex requests while maintaining anatomical accuracy.',
#   'feature2_title': 'Style Adaptation Engine',
#   'feature2_content': 'Switch between artistic styles—from lifelike photorealism to illustrated aesthetics—while preserving custom details. The AI maintains consistent quality across all output formats.',
#   'feature3_title': 'Ethical AI Framework',
#   'feature3_content': 'Built with responsible innovation principles, our generator uses anonymized data processing and content filters to ensure appropriate, copyright-compliant outputs.',
#   'cta_title': 'Elevate Your Creative Projects',
#   'cta_content': 'Beyond image generation, leverage our AI toolkit for digital art enhancement, 3D model prototyping, and dynamic pose sequencing. Integrate generated assets into animations, concept art, or design workflows with full commercial rights.',
#   'faq_dict': {'What input details improve results?': 'Specify lighting direction, fabric textures, color schemes, and perspective preferences. The AI interprets complex descriptions best when provided with structured details.',
#    'Are generated images royalty-free?': 'All outputs include commercial usage rights, with no attribution required. Generated content complies with major platform content policies.',
#    'How does AI ensure anatomical accuracy?': 'The system references proportional databases and movement physics models to maintain realistic human forms in varied poses.',
#    'Can I batch-process multiple images?': 'Premium subscribers can queue multiple generations and access bulk editing tools for efficient workflow scaling.',
#    'What security measures protect user data?': 'All prompts and generated content are encrypted, with no personal data storage. Users retain full ownership of their creations.'},
#   'title_seo': 'AI Fashion Generator: Custom Imagery Tool | [Brand]',
#   'description_seo': 'Advanced AI generator for custom fashion visuals. Create detailed, style-adaptive images with commercial rights. Start designing now.'},
#  'cute girl': {'title': 'AI Cute Girl Generator',
#   'subtitle': 'Craft custom AI-generated anime-style characters with precision. Generate unique, high-quality images in seconds using advanced neural networks—no artistic skills required.',
#   'how_to_use_title': 'How to Use the AI Cute Girl Generator:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': 'Enter a detailed description of your desired character in the prompt field. Include specifics like hairstyle, outfit, expression, and background elements to guide the AI’s creative process.',
#   'how_to_step2_title': 'Generate & Refine',
#   'how_to_step2_content': "Click 'Generate' to let our AI process your request. Preview the initial results and use our refinement tools to adjust details like color palettes or poses for optimal customization.",
#   'how_to_step3_title': 'Export & Share',
#   'how_to_step3_content': 'Download your final design in PNG or JPEG format. Use your AI-generated character for avatars, creative projects, or social media—all outputs are royalty-free.',
#   'feature1_title': 'Style Customization',
#   'feature1_content': 'Tailor every aspect of your character with granular controls for art style, accessories, and settings. Switch between anime, chibi, or semi-realistic aesthetics seamlessly.',
#   'feature2_title': 'High-Resolution Output',
#   'feature2_content': 'Generate crisp 4K-ready images with intricate details, from textured clothing to dynamic lighting effects. Ideal for professional designers and content creators.',
#   'feature3_title': 'Real-Time Editing',
#   'feature3_content': 'Modify generated images instantly using AI-powered editing tools. Adjust facial features, backgrounds, or color schemes without restarting the generation process.',
#   'cta_title': 'Unlock Advanced Creative Tools',
#   'cta_content': 'Beyond character generation, explore our suite of AI-powered design resources. Enhance images with automated upscaling, create animated versions of your characters, or integrate outputs into video projects—all within a secure, user-friendly platform.',
#   'faq_dict': {'Is there an age restriction for using this tool?': 'Our platform is designed for users aged 13+ and complies with all content safety regulations. All outputs maintain appropriate, non-explicit aesthetics.',
#    'Can I replicate specific anime art styles?': 'Yes—our AI recognizes 50+ established anime and manga styles. Reference popular series or mix elements to create hybrid designs.',
#    'Are generated images copyrighted?': 'Users retain full commercial rights to their creations. We recommend reviewing local regulations regarding AI-generated content usage.',
#    'How long does generation typically take?': 'Most images complete in under 10 seconds. Complex requests with multiple refinement steps may take up to 1 minute.',
#    'Is my personal data secure?': 'We employ military-grade encryption and never store payment details or prompt histories. Your creative privacy is our priority.'},
#   'title_seo': 'AI Cute Girl Generator: Custom Anime Character Creator',
#   'description_seo': 'Design unique AI-generated anime characters instantly. Customize styles, poses, and details with advanced AI tools. Start creating now!'},
#  'girl in underwear': {'title': 'AI Underwear Model Generator',
#   'subtitle': 'Craft hyper-realistic AI-generated models with precision using advanced neural networks. Perfect for fashion concepts, design projects, and creative exploration.',
#   'how_to_use_title': 'Create in 3 Simple Steps:',
#   'how_to_step1_title': 'Define Your Concept',
#   'how_to_step1_content': "Enter descriptive prompts about body type, pose, lighting, and stylistic preferences. Use keywords like 'athletic build' or 'studio lighting' to guide our AI model.",
#   'how_to_step2_title': 'AI Rendering Process',
#   'how_to_step2_content': 'Our proprietary GAN architecture processes your input in 15-20 seconds, generating photorealistic textures and anatomically proportional renders while maintaining ethical AI standards.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Use our integrated editing tools to adjust lighting, backgrounds, or proportions. Export 4K resolution PNG/JPG files ready for commercial or personal use.',
#   'feature1_title': 'Anatomic Precision Engine',
#   'feature1_content': 'AI-powered biomechanical modeling ensures natural proportions and movement authenticity, with 42 adjustable parameters for personalized results.',
#   'feature2_title': 'Ethical AI Framework',
#   'feature2_content': 'Built-in content moderation and privacy-first architecture guarantee secure, responsible generation aligned with AI ethics standards.',
#   'feature3_title': 'Style Transfer Capabilities',
#   'feature3_content': 'Apply diverse artistic styles from photorealistic to illustrated concepts through our patented neural style transfer technology.',
#   'cta_title': 'Beyond Basic Image Generation',
#   'cta_content': 'Unlock professional-grade creative tools with our AI Studio Suite - generate base models, edit textures, or create animation sequences. Start with 10 free credits to explore our enterprise-grade platform risk-free.',
#   'faq_dict': {'What technical specifications do generated images have?': 'All outputs are 4096x4096px resolution with 300 DPI, supporting PNG, JPG, and WebP formats for professional workflows.',
#    'Can I use these images commercially?': 'Yes, all generated content includes full commercial rights with no attribution required under our Standard License Agreement.',
#    'How does the platform ensure ethical usage?': 'We employ real-time content analysis and adhere to strict AI ethics guidelines through our partnership with the Responsible AI Institute.',
#    'What hardware is required?': 'Our cloud-based solution works on any modern browser - no specialized hardware needed. Enterprise plans offer API integration.',
#    'Is user data stored after generation?': 'All input prompts and generated images are automatically purged from our servers within 24 hours unless explicitly saved to your private cloud vault.'},
#   'title_seo': 'AI Model Generator: Custom Underwear Designs & Styling',
#   'description_seo': 'Create AI-generated fashion models with precision. Advanced customization, ethical AI, and commercial-ready outputs. Start designing today.'},
#  'girls kissing': {'title': 'AI Girls Kissing Generator',
#   'subtitle': 'Craft bespoke AI-generated visuals of dynamic interactions with cutting-edge technology. Generate high-quality, artistic concepts in seconds—no design experience required.',
#   'how_to_use_title': 'How to Use the AI Girls Kissing Generator:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': "Input your creative concept into the prompt field, using descriptive keywords to outline poses, expressions, and artistic style. Click 'Generate' to initiate the AI process.",
#   'how_to_step2_title': 'AI Processing',
#   'how_to_step2_content': 'Our advanced algorithms analyze your input to create lifelike compositions. Wait moments for the system to render your vision with precision and detail.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Preview your AI-generated artwork, adjust parameters if needed, then download in your preferred format. Images are ready for personal or commercial projects.',
#   'feature1_title': 'Dynamic Customization',
#   'feature1_content': 'Fine-tune every detail—from lighting to composition—using intuitive controls. Create unique interactions that align perfectly with your creative vision.',
#   'feature2_title': 'Intuitive Interface',
#   'feature2_content': 'Designed for seamless navigation, our platform enables effortless generation regardless of technical skill. Focus on creativity while our AI handles complex rendering.',
#   'feature3_title': 'Advanced AI Rendering',
# ...
#   'how_to_step2_title': 'AI Generation',
#   'how_to_step2_content': 'Our neural network processes your request in under 15 seconds, rendering photorealistic beach scenes with precise attention to lighting, proportions, and environmental details.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Download your high-resolution image (up to 4K) in PNG or JPEG format. Use our built-in upscaling tools to enhance details or generate variations with one click.',
#   'feature1_title': 'Photorealistic AI-Generated Imagery',
#   'feature1_content': 'Produce beach scenes with authentic wave physics, realistic skin textures, and accurate lighting using our proprietary StyleFusion AI engine. Achieve professional-grade results without photography equipment.',
#   'feature2_title': 'Intuitive Customization Controls',
#   'feature2_content': 'Adjust specific elements post-generation with our AI editing suite—modify backgrounds, swap outfits, or change facial expressions through simple text prompts.',
#   'feature3_title': 'Rapid Generation Technology',
#   'feature3_content': 'Process 3x faster than standard AI generators while maintaining 4K resolution. Our optimized neural networks handle complex requests like dynamic poses and water reflections effortlessly.',
#   'cta_title': 'Expand Your Creative Toolkit',
#   'cta_content': 'Beyond beach art generation, access our full suite of AI-powered design tools. Create matching ocean landscapes, transform images into animated videos, or batch-process summer-themed content sets. Start with 5 free credits to explore professional-grade AI capabilities.',
#   'faq_dict': {'What technical specs do the images have?': 'All outputs are 300 DPI resolution-ready, supporting CMYK/RGB color profiles for both digital and print applications.',
#    'Are there usage limits?': 'Free tier includes 10 monthly generations. Premium plans offer unlimited HD renders and priority queue access.',
#    'Can I edit existing photos with this tool?': "Yes—upload reference images to guide the AI's style interpretation while maintaining full creative control.",
#    'How does AI ensure diverse representation?': 'Our systems are trained on ethically sourced datasets with 120+ global ethnicities and body type parameters for inclusive generation.',
#    'Is commercial use permitted?': 'All generated images include full commercial rights. Attribution is optional but appreciated.'},
#   'title_seo': 'AI Beach Girl Generator: Custom Summer-Themed AI Art',
#   'description_seo': 'Create personalized beach scenes with AI—generate lifelike summer characters & backgrounds in seconds. Professional-grade tools for marketers & creators.'},
#  'topless girl': {'title': 'AI Topless Girl Generator',
#   'subtitle': 'Transform your creative vision into stunning AI-generated art with cutting-edge image synthesis technology. Explore limitless customization while maintaining full creative control.',
#   'how_to_use_title': 'How to Create AI-Generated Art:',
#   'how_to_step1_title': 'Describe Your Concept',
#   'how_to_step1_content': 'Enter descriptive text about the style, composition, and artistic elements you want to incorporate. Use our AI prompt builder for optimal results with artistic direction.',
#   'how_to_step2_title': 'AI Processing',
#   'how_to_step2_content': 'Our neural networks analyze your input using advanced stable diffusion models to generate multiple artistic interpretations while maintaining ethical AI standards.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Use our editing tools to adjust lighting, composition, and styling before exporting your high-resolution artwork in PNG or JPEG formats.',
#   'feature1_title': 'Advanced Neural Rendering',
#   'feature1_content': 'Leverage state-of-the-art generative adversarial networks (GANs) that produce photorealistic textures and natural lighting effects while preserving artistic integrity.',
#   'feature2_title': 'Ethical AI Framework',
#   'feature2_content': 'Built with responsible innovation principles, our AI strictly follows content guidelines and privacy protections throughout the generation process.',
#   'feature3_title': 'Professional-Grade Output',
#   'feature3_content': 'Generate print-ready 4K resolution images with full commercial usage rights, ideal for digital artists, content creators, and design professionals.',
#   'cta_title': 'Unlock Creative Possibilities',
#   'cta_content': 'Explore our complete suite of AI art tools for character design, concept art generation, and visual storytelling. Join 50,000+ creatives using our platform to enhance their workflows with ethical AI solutions.',
#   'faq_dict': {'How does the AI ensure ethical generation?': 'Our system uses advanced content moderation algorithms and adheres to strict AI ethics guidelines throughout the generation process.',
#    'Can I use generated images commercially?': 'All outputs include full commercial rights, with optional extended licenses available for enterprise users.',
#    'What input guidelines should I follow?': 'Users must provide descriptive, artistic prompts that comply with our content policy. Our AI automatically filters inappropriate requests.',
#    'How is user privacy protected?': 'All generation sessions are anonymous and encrypted. Input prompts/outputs are never stored or shared with third parties.',
#    'What resolution are generated images?': 'Outputs default to 4K resolution (4096x4096px) with options for vector formats and layered PSD files.'},
#   'title_seo': 'AI Art Generator: Ethical Character Design Tool',
#   'description_seo': 'Create custom AI-generated art with advanced neural networks. Professional-grade outputs, full commercial rights, and ethical AI standards.'},
#  'petite girl': {'title': 'AI Petite Girl Generator',
#   'subtitle': 'Create custom AI-generated petite characters in seconds with cutting-edge technology. No artistic skills required—simply describe your vision and let our AI deliver professional-grade stylized imagery.',
#   'how_to_use_title': 'How to Use AI Petite Girl Generator:',
#   'how_to_step1_title': 'Describe Your Character',
#   'how_to_step1_content': "Enter detailed attributes in the prompt box, including hairstyle, clothing preferences, and personality traits. Use specific keywords like 'anime-inspired' or 'realistic rendering' to guide the AI's creative process.",
#   'how_to_step2_title': 'Initiate Generation',
#   'how_to_step2_content': "Click 'Generate' to activate our advanced neural networks. The system typically processes requests in 10-15 seconds, crafting multiple variations based on your input parameters.",
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Review your AI-generated characters, adjust prompts for fine-tuning, then download 4K resolution images in PNG or JPG formats. All outputs are royalty-free for personal or commercial projects.',
#   'feature1_title': 'Advanced Style Customization',
#   'feature1_content': 'Tailor every detail from facial expressions to background settings using natural language prompts. Our AI interprets complex descriptions to produce coherent, visually stunning character designs.',
#   'feature2_title': 'Multi-Format Output',
#   'feature2_content': 'Generate ready-to-use assets optimized for digital platforms, print media, or 3D modeling pipelines. Batch processing available for creators needing multiple character variations.',
#   'feature3_title': 'Ethical AI Framework',
#   'feature3_content': 'Built with responsible AI principles, our generator employs content safeguards while maintaining creative flexibility. All outputs are watermarked to ensure transparent AI attribution.',
#   'cta_title': 'Elevate Your Creative Projects',
#   'cta_content': 'Beyond character generation, integrate your AI creations into animations, game assets, or digital artwork using our companion tools. Join 50,000+ designers and storytellers revolutionizing their workflow with AI-powered creativity.',
#   'faq_dict': {'What technical specifications do the images have?': 'Images are generated at 4096x4096 resolution with 300 DPI, suitable for professional printing and digital display.',
#    'Can I create characters for commercial branding?': 'Yes, all generated images include full commercial rights. We recommend reviewing our content guidelines for specific use cases.',
#    'How does the AI handle unique style requests?': 'Our model supports 15+ art styles including cel-shaded, photorealistic, and watercolor. Specify your desired aesthetic in the prompt for best results.',
#    'Is there a limit on generations?': 'Free tier includes 25 monthly generations. Premium plans offer unlimited access with priority processing and advanced editing features.',
#    'How is user privacy maintained?': 'All prompts and generated images are encrypted, with optional automatic deletion after 72 hours. We never share or replicate user-created content.'},
#   'title_seo': 'AI Petite Girl Generator | Custom Character Design Tool',
#   'description_seo': 'Create unique AI-generated petite characters with advanced customization. Professional-grade art for creators & designers. Start generating now!'},
#  'pregnant girl': {'title': 'AI Pregnancy Portrait Generator',
#   'subtitle': 'Craft personalized maternity portraits with cutting-edge AI technology. Generate lifelike pregnancy-themed imagery in seconds—no design skills required. Simply describe your vision and let our AI create stunning results.',
#   'how_to_use_title': 'How to Use the AI Pregnancy Portrait Generator:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': "Enter a detailed description in the prompt box, specifying preferences for poses, clothing, backgrounds, and artistic styles. Use keywords like 'soft lighting,' 'modern maternity wear,' or 'nature setting' to guide the AI.",
#   'how_to_step2_title': 'AI Generation Process',
#   'how_to_step2_content': 'Our advanced model processes your request using deep learning algorithms to generate anatomically accurate and aesthetically balanced maternity portraits. Results typically appear in 10-15 seconds.',
#   'how_to_step3_title': 'Refine & Export',
#   'how_to_step3_content': 'Download high-resolution PNG or JPEG files instantly. Use built-in editing tools to adjust lighting, colors, or composition before saving your final AI-generated portrait.',
#   'feature1_title': 'Customizable Maternity Portraits',
#   'feature1_content': 'Tailor every detail using natural language prompts—from trimester stage to clothing style. Our AI interprets complex requests to create unique, meaningful pregnancy-themed imagery.',
#   'feature2_title': 'Intuitive AI Interface',
#   'feature2_content': "Generate professional-grade maternity art without technical expertise. The platform's smart suggestion system helps refine prompts for optimal results.",
#   'feature3_title': 'Photorealistic Results',
#   'feature3_content': 'Leverage state-of-the-art generative adversarial networks (GANs) that produce images with realistic textures, lighting, and anatomical accuracy while maintaining artistic flexibility.',
#   'cta_title': 'Transform Your Creative Process Today',
#   'cta_content': 'Beyond portrait generation, our platform offers AI-powered editing tools to enhance existing photos, create maternity-themed digital art collections, or design custom pregnancy journals. Experience how AI can elevate your personal or professional projects with ethically-developed technology.',
#   'faq_dict': {'How does the AI ensure anatomical accuracy?': 'Our models are trained on diverse medical-approved datasets with ethical oversight, ensuring proportional and realistic representations while maintaining artistic freedom.',
#    'Can I generate images for commercial projects?': 'All generated content includes commercial usage rights. Review our licensing agreement for specific terms regarding redistribution and modification.',
#    'What privacy measures protect my data?': 'We employ end-to-end encryption and never store prompt histories or generated images. All processing occurs through temporary secure sessions.',
#    'Are there content guidelines for prompts?': 'Yes, our system automatically filters requests against ethical AI guidelines. Generated content focuses on artistic maternity themes and family-friendly contexts.',
#    'Can I request style variations?': "Absolutely. Specify art styles like 'watercolor,' 'digital art,' or 'studio photography' in your prompts. Our AI adapts to diverse aesthetic preferences."},
#   'title_seo': 'AI Pregnancy Portrait Generator | Custom Maternity Images',
#   'description_seo': 'Create personalized AI-generated maternity portraits with advanced technology. Fast, secure, and artistically flexible. Design your perfect pregnancy-themed imagery now.'},
#  'valhalla girl': {'title': 'AI Valhalla Girl Generator',
#   'subtitle': 'Craft legendary Norse-inspired characters with cutting-edge AI. Generate high-quality Valhalla warrior images in seconds—no design skills required.',
#   'how_to_use_title': 'How to Create Your AI Valhalla Girl:',
#   'how_to_step1_title': 'Describe Your Vision',
#   'how_to_step1_content': "Enter a detailed prompt describing your ideal Valhalla warrior, including elements like armor style, weaponry, environment, and personality traits. Use descriptive keywords to guide the AI's creative process.",
#   'how_to_step2_title': 'Generate Your Artwork',
#   'how_to_step2_content': 'Our AI processes your input using advanced diffusion models, analyzing 50+ artistic parameters to create a unique Valkyrie-inspired character. Typical generation time is 8-12 seconds.',
#   'how_to_step3_title': 'Refine & Download',
#   'how_to_step3_content': 'Adjust details using our precision editing tools, then export your 4K-resolution Valhalla girl in PNG or JPEG format. All images include commercial-use licensing.',
#   'feature1_title': 'Mythic Customization Engine',
#   'feature1_content': 'Our proprietary AI architecture lets you control 15+ visual attributes including armor detailing, facial features, and battle poses while maintaining authentic Norse aesthetic coherence.',
#   'feature2_title': 'Cinematic-Grade Resolution',
#   'feature2_content': 'Generate images at 4096x4096 resolution with 16-bit color depth. Advanced upscaling technology preserves intricate details like chainmail textures and glowing rune effects.',
#   'feature3_title': 'Multi-Style Versatility',
#   'feature3_content': 'Create anything from historically inspired Viking warriors to fantasy battle maidens. Switch between realistic, comic book, or cel-shaded art styles with a single parameter adjustment.',
#   'cta_title': 'Forge Your Legend Today',
#   'cta_content': 'Join 50,000+ creators using AI Valhalla Generator for game assets, book illustrations, and digital art projects. Get 5 free generations when you create your professional account.',
#   'faq_dict': {'What makes this different from other AI art tools?': 'Our specialized model is trained on 2M+ Nordic art references and historical manuscripts to ensure culturally authentic Valhalla aesthetics.',
#    'Can I use these images commercially?': 'All generated images include full commercial rights. Review our licensing agreement for specific usage guidelines.',
#    'How detailed should my prompts be?': 'Ideal prompts include 3-5 descriptive sentences covering appearance, equipment, background, and mood. Use our template library for inspiration.',
#    'What hardware is required?': 'Our cloud-based generator works on any device. Even complex 4K renders process remotely for instant browser results.',
#    'Is there NSFW content filtering?': 'Our AI automatically applies mythological authenticity filters while maintaining creative flexibility. Manual moderation controls are available for professional accounts.'},
#   'title_seo': 'AI Valhalla Girl Generator: Create Mythic Norse Characters',
#   'description_seo': 'Generate custom Valhalla warriors with AI. Create high-quality Norse-inspired character art instantly. Professional-grade tools for creators.'}}

# %%
os.environ["PERPLEXITY_API_KEY"] = "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"

if __name__ == "__main__":
    main(ai_girls_results)
# Out:
# Generating landing pages:   0%|                                                                                                                                                                                                                                                | 0/26 [00:00<?, ?it/s]
# skipping nude girl because it already exists
# skipping sexy girl because it already exists
# skipping hot girl because it already exists
# skipping little girl because it already exists
# skipping teen girl because it already exists
# skipping nn girl because it already exists
# skipping bikini girl because it already exists
# skipping anime girl because it already exists
# skipping tween girl because it already exists
# skipping girls porn because it already exists
# skipping young girl because it already exists
# skipping girl in panties because it already exists
# skipping cute girl because it already exists
# skipping girl in underwear because it already exists
# skipping girls kissing because it already exists
# skipping school girls because it already exists
# skipping asign girls because it already exists
# skipping girl in lingerie because it already exists
# skipping girl satin because it already exists
# skipping muscle girl because it already exists
# skipping beach girl because it already exists
# skipping topless girl because it already exists
# skipping petite girl because it already exists
# skipping pregnant girl because it already exists
# skipping valhalla girl because it already exists
#
# Generating landing page for: asian girls
# 2025-04-01 15:57:15,067:INFO - HTTP Request: POST https://api.perplexity.ai/chat/completions "HTTP/1.1 200 OK"
# Generating landing pages: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:21<00:00,  1.20it/s]
# Successfully generated content for asian girls
#
# Generated 26 landing pages out of 26 types
# Results saved to ai_girls_landing_pages.json
# CSV file also created: ai_girls_landing_pages.csv
